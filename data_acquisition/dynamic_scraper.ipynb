# %% [markdown]
# # Import

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import json

# %% [markdown]
# # Scraping Name and Score

# %% [markdown]
# Scraping name and score from the website https://pvpoke.com/rankings/. <br>
# Store Data in raw_data/pokemon_name_rank.json.

# %%
def scrape_rankings_names_scores_to_json():
    # Set up the Selenium WebDriver
    driver = webdriver.Chrome()

    try:
        # Navigate to the rankings page
        url = 'https://pvpoke.com/rankings/'
        driver.get(url)

        # Wait for the page to load completely
        time.sleep(15)

        # Get the page source and parse it with BeautifulSoup
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')

        # Extract Pokémon rankings data
        pokemon_blocks = soup.find_all('div', class_='rank')
        data = []

        for pokemon in pokemon_blocks:
            name = pokemon.find('span', class_='name').text if pokemon.find('span', class_='name') else "No name"
            score = pokemon.find('div', class_='rating score-rating').text if pokemon.find('div', class_='rating score-rating') else "No score"

            data.append({"name": name, "score": score})

        # Filter out entries with 'No score'
        data = [entry for entry in data if entry['score'] != "No score"]

        # Save data to a JSON file in the raw_data folder
        output_path = 'raw_data/pokemon_name_rank.json'
        with open(output_path, 'w') as f:
            json.dump(data, f, indent=4)

        print(f"Data has been saved to {output_path}")

    finally:
        # Quit the driver
        driver.quit()

# %%
# Call the function
scrape_rankings_names_scores_to_json()
# Out:
# Data has been saved to raw_data/pokemon_name_rank.json

# %% [markdown]
# # Scraping stats and moves

# %%
def scrape_all_pokemon_stats():
    input_path = 'raw_data/pokemon_name_rank.json'
    output_path = 'raw_data/pokemon_stats_moves.json'
    base_url = 'https://pvpoke.com/rankings/all/1500/overall/'
    driver = webdriver.Chrome()

    url = 'https://pvpoke.com/rankings/'
    driver.get(url)
    time.sleep(10)

    try:
        # Read Pokémon names from the input JSON file
        with open(input_path, 'r') as f:
            pokemon_list = json.load(f)

        # Initialize the output JSON file
        with open(output_path, 'w') as f:
            json.dump([], f)

        for pokemon in pokemon_list:
            name = pokemon['name']
            # Replace parentheses, apostrophes, spaces, and hyphens with underscores in the URL
            formatted_name = name.replace('(', '').replace(')', '').replace(' ', '_').replace('-','_').replace("'", '')
            url = f"{base_url}{formatted_name.lower()}/"

            driver.get(url)
            time.sleep(7)
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')

            # Get detailed stats
            stat_details = soup.find('div', class_='stat-details clear')
            filtered_stats = {}
            if stat_details:
                for stat_row in stat_details.find_all('div', class_='stat-row'):
                    label = stat_row.find('div', class_='label')
                    value = stat_row.find('div', class_='value')
                    if label and value:
                        label_text = label.text.strip()
                        value_text = value.text.strip()
                        if label_text in ['Attack', 'Defense', 'Overall', 'Stamina']:
                            filtered_stats[label_text] = value_text

            # Get fast moves and their details
            fast_moves_section = soup.find('div', class_='moveset fast show-stats clear')
            fast_moves = []
            recommended_fast_move = None
            
            if fast_moves_section:
                move_elements = fast_moves_section.find_all('div', class_='move-detail-template')
                for move in move_elements:
                    if 'hide' not in move.get('class', []):
                        name_span = move.find('span', class_='name')
                        if name_span:
                            move_name = name_span.text.strip()
                            fast_moves.append(move_name)
                            # Check if this move is recommended (has 'selected' class)
                            if 'selected' in move.get('class', []):
                                recommended_fast_move = move_name

            # Get charged moves and their details
            charged_moves_section = soup.find('div', class_='moveset charged show-stats clear')
            charged_moves = []
            recommended_charged_moves = []
            
            if charged_moves_section:
                move_elements = charged_moves_section.find_all('div', class_='move-detail-template')
                for move in move_elements:
                    if 'hide' not in move.get('class', []):
                        name_span = move.find('span', class_='name')
                        if name_span:
                            move_name = name_span.text.strip()
                            charged_moves.append(move_name)
                            # Check if this move is recommended (has 'selected' class)
                            if 'selected' in move.get('class', []):
                                recommended_charged_moves.append(move_name)

            # Save Pokémon name, stats, moves, and recommended moves
            pokemon_data = {
                'name': name,
                'filtered_stats': filtered_stats,
                'fast_moves': fast_moves,
                'charged_moves': charged_moves,
                'recommended_fast_move': recommended_fast_move,
                'recommended_charged_moves': recommended_charged_moves
            }

            # Append the data to the JSON file
            with open(output_path, 'r+') as f:
                existing_data = json.load(f)
                existing_data.append(pokemon_data)
                f.seek(0)
                json.dump(existing_data, f, indent=4)

            # Print the data in a single line to the terminal
            print(f"Name: {name}, Stats: {filtered_stats}, Fast Moves: {fast_moves}, Charged Moves: {charged_moves}, Recommended Fast: {recommended_fast_move}, Recommended Charged: {recommended_charged_moves}")

        print(f"All Pokémon stats have been saved to {output_path}")


    finally:
        driver.quit()

# Call the function
scrape_all_pokemon_stats()
# Out:
# Name: Clodsire, Stats: {'Attack': '94.2', 'Defense': '119.4', 'Stamina': '209', 'Overall': '2352'}, Fast Moves: ['Poison Sting', 'Mud Shot'], Charged Moves: ['Stone Edge', 'Earthquake', 'Sludge Bomb', 'Megahorn*', 'Water Pulse', 'Acid Spray'], Recommended Fast: Poison Sting, Recommended Charged: ['Stone Edge', 'Earthquake']
# Name: Diggersby, Stats: {'Attack': '96.3', 'Defense': '141.1', 'Stamina': '171', 'Overall': '2325'}, Fast Moves: ['Quick Attack', 'Mud Shot'], Charged Moves: ['Scorching Sands', 'Fire Punch', 'Return†', 'Dig', 'Earthquake', 'Hyper Beam'], Recommended Fast: Quick Attack, Recommended Charged: ['Scorching Sands', 'Fire Punch']
# Name: Diggersby, Stats: {'Attack': '96.3', 'Defense': '141.1', 'Stamina': '171', 'Overall': '2325'}, Fast Moves: ['Quick Attack', 'Mud Shot'], Charged Moves: ['Scorching Sands', 'Fire Punch', 'Return†', 'Dig', 'Earthquake', 'Hyper Beam'], Recommended Fast: Quick Attack, Recommended Charged: ['Scorching Sands', 'Fire Punch']
# Name: Forretress, Stats: {'Attack': '110.2', 'Defense': '141.6', 'Stamina': '130', 'Overall': '2029'}, Fast Moves: ['Volt Switch', 'Bug Bite', 'Struggle Bug'], Charged Moves: ['Rock Tomb', 'Mirror Shot', 'Heavy Slam', 'Earthquake', 'Return†', 'Sand Tomb'], Recommended Fast: Bug Bite, Recommended Charged: ['Rock Tomb', 'Sand Tomb']
# Name: Forretress, Stats: {'Attack': '110.2', 'Defense': '141.6', 'Stamina': '130', 'Overall': '2029'}, Fast Moves: ['Volt Switch', 'Bug Bite', 'Struggle Bug'], Charged Moves: ['Rock Tomb', 'Mirror Shot', 'Heavy Slam', 'Earthquake', 'Return†', 'Sand Tomb'], Recommended Fast: Bug Bite, Recommended Charged: ['Rock Tomb', 'Sand Tomb']
# Name: Lapras, Stats: {'Attack': '104.6', 'Defense': '113.9', 'Stamina': '179', 'Overall': '2136'}, Fast Moves: ['Psywave', 'Ice Shard*', 'Water Gun', 'Frost Breath'], Charged Moves: ['Sparkling Aria', 'Ice Beam*', 'Surf', 'Skull Bash', 'Dragon Pulse*', 'Blizzard', 'Hydro Pump'], Recommended Fast: Psywave, Recommended Charged: ['Sparkling Aria', 'Ice Beam*']
# Name: Lapras, Stats: {'Attack': '104.6', 'Defense': '113.9', 'Stamina': '179', 'Overall': '2136'}, Fast Moves: ['Psywave', 'Ice Shard*', 'Water Gun', 'Frost Breath'], Charged Moves: ['Sparkling Aria', 'Ice Beam*', 'Surf', 'Skull Bash', 'Dragon Pulse*', 'Blizzard', 'Hydro Pump'], Recommended Fast: Psywave, Recommended Charged: ['Sparkling Aria', 'Ice Beam*']
# Name: Jellicent, Stats: {'Attack': '106.6', 'Defense': '124.3', 'Stamina': '157', 'Overall': '2082'}, Fast Moves: ['Hex', 'Bubble'], Charged Moves: ['Surf', 'Shadow Ball', 'Ice Beam', 'Bubble Beam'], Recommended Fast: Hex, Recommended Charged: ['Surf', 'Shadow Ball']
# Name: Jellicent, Stats: {'Attack': '106.6', 'Defense': '124.3', 'Stamina': '157', 'Overall': '2082'}, Fast Moves: ['Hex', 'Bubble'], Charged Moves: ['Surf', 'Shadow Ball', 'Ice Beam', 'Bubble Beam'], Recommended Fast: Hex, Recommended Charged: ['Surf', 'Shadow Ball']
# Name: Corsola (Galarian), Stats: {'Attack': '99.5', 'Defense': '162', 'Stamina': '139', 'Overall': '2243'}, Fast Moves: ['Astonish', 'Tackle'], Charged Moves: ['Night Shade', 'Power Gem', 'Rock Blast'], Recommended Fast: Astonish, Recommended Charged: ['Night Shade', 'Power Gem']
# Name: Corsola (Galarian), Stats: {'Attack': '99.5', 'Defense': '162', 'Stamina': '139', 'Overall': '2243'}, Fast Moves: ['Astonish', 'Tackle'], Charged Moves: ['Night Shade', 'Power Gem', 'Rock Blast'], Recommended Fast: Astonish, Recommended Charged: ['Night Shade', 'Power Gem']
# Name: Dusclops, Stats: {'Attack': '103', 'Defense': '198.9', 'Stamina': '106', 'Overall': '2173'}, Fast Moves: ['Hex', 'Feint Attack'], Charged Moves: ['Shadow Punch', 'Ice Punch', 'Fire Punch', 'Return†', 'Poltergeist'], Recommended Fast: Hex, Recommended Charged: ['Shadow Punch', 'Ice Punch']
# Name: Dusclops, Stats: {'Attack': '103', 'Defense': '198.9', 'Stamina': '106', 'Overall': '2173'}, Fast Moves: ['Hex', 'Feint Attack'], Charged Moves: ['Shadow Punch', 'Ice Punch', 'Fire Punch', 'Return†', 'Poltergeist'], Recommended Fast: Hex, Recommended Charged: ['Shadow Punch', 'Ice Punch']
# Name: Gligar (Shadow), Stats: {'Attack': '108', 'Defense': '146.2', 'Stamina': '130', 'Overall': '2053'}, Fast Moves: ['Fury Cutter', 'Wing Attack'], Charged Moves: ['Aerial Ace', 'Night Slash', 'Dig', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aerial Ace', 'Dig']
# Name: Gligar (Shadow), Stats: {'Attack': '108', 'Defense': '146.2', 'Stamina': '130', 'Overall': '2053'}, Fast Moves: ['Fury Cutter', 'Wing Attack'], Charged Moves: ['Aerial Ace', 'Night Slash', 'Dig', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aerial Ace', 'Dig']
# Name: Samurott, Stats: {'Attack': '129', 'Defense': '102.1', 'Stamina': '132', 'Overall': '1740'}, Fast Moves: ['Fury Cutter', 'Waterfall'], Charged Moves: ['Hydro Cannon*', 'Razor Shell', 'Megahorn', 'Liquidation', 'Blizzard', 'Hydro Pump'], Recommended Fast: Fury Cutter, Recommended Charged: ['Hydro Cannon*', 'Megahorn']
# Name: Samurott, Stats: {'Attack': '129', 'Defense': '102.1', 'Stamina': '132', 'Overall': '1740'}, Fast Moves: ['Fury Cutter', 'Waterfall'], Charged Moves: ['Hydro Cannon*', 'Razor Shell', 'Megahorn', 'Liquidation', 'Blizzard', 'Hydro Pump'], Recommended Fast: Fury Cutter, Recommended Charged: ['Hydro Cannon*', 'Megahorn']
# Name: Gligar, Stats: {'Attack': '108', 'Defense': '146.2', 'Stamina': '130', 'Overall': '2053'}, Fast Moves: ['Fury Cutter', 'Wing Attack'], Charged Moves: ['Aerial Ace', 'Night Slash', 'Dig', 'Return†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aerial Ace', 'Dig']
# Name: Gligar, Stats: {'Attack': '108', 'Defense': '146.2', 'Stamina': '130', 'Overall': '2053'}, Fast Moves: ['Fury Cutter', 'Wing Attack'], Charged Moves: ['Aerial Ace', 'Night Slash', 'Dig', 'Return†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aerial Ace', 'Dig']
# Name: Clodsire, Stats: {'Attack': '94.2', 'Defense': '119.4', 'Stamina': '209', 'Overall': '2352'}, Fast Moves: ['Poison Sting', 'Mud Shot'], Charged Moves: ['Stone Edge', 'Earthquake', 'Sludge Bomb', 'Megahorn*', 'Water Pulse', 'Acid Spray'], Recommended Fast: Poison Sting, Recommended Charged: ['Stone Edge', 'Earthquake']
# Name: Clodsire, Stats: {'Attack': '94.2', 'Defense': '119.4', 'Stamina': '209', 'Overall': '2352'}, Fast Moves: ['Poison Sting', 'Mud Shot'], Charged Moves: ['Stone Edge', 'Earthquake', 'Sludge Bomb', 'Megahorn*', 'Water Pulse', 'Acid Spray'], Recommended Fast: Poison Sting, Recommended Charged: ['Stone Edge', 'Earthquake']
# Name: Jumpluff (Shadow), Stats: {'Attack': '97', 'Defense': '153.4', 'Stamina': '155', 'Overall': '2308'}, Fast Moves: ['Fairy Wind', 'Bullet Seed', 'Infestation'], Charged Moves: ['Acrobatics*', 'Aerial Ace', 'Energy Ball', 'Dazzling Gleam', 'Solar Beam', 'Frustration†'], Recommended Fast: Fairy Wind, Recommended Charged: ['Acrobatics*', 'Aerial Ace']
# Name: Jumpluff (Shadow), Stats: {'Attack': '97', 'Defense': '153.4', 'Stamina': '155', 'Overall': '2308'}, Fast Moves: ['Fairy Wind', 'Bullet Seed', 'Infestation'], Charged Moves: ['Acrobatics*', 'Aerial Ace', 'Energy Ball', 'Dazzling Gleam', 'Solar Beam', 'Frustration†'], Recommended Fast: Fairy Wind, Recommended Charged: ['Acrobatics*', 'Aerial Ace']
# Name: Feraligatr, Stats: {'Attack': '123.2', 'Defense': '117.9', 'Stamina': '124', 'Overall': '1804'}, Fast Moves: ['Shadow Claw', 'Ice Fang', 'Water Gun*', 'Waterfall', 'Bite'], Charged Moves: ['Hydro Cannon*', 'Crunch', 'Ice Beam', 'Hydro Pump'], Recommended Fast: Shadow Claw, Recommended Charged: ['Hydro Cannon*', 'Ice Beam']
# Name: Feraligatr, Stats: {'Attack': '123.2', 'Defense': '117.9', 'Stamina': '124', 'Overall': '1804'}, Fast Moves: ['Shadow Claw', 'Ice Fang', 'Water Gun*', 'Waterfall', 'Bite'], Charged Moves: ['Hydro Cannon*', 'Crunch', 'Ice Beam', 'Hydro Pump'], Recommended Fast: Shadow Claw, Recommended Charged: ['Hydro Cannon*', 'Ice Beam']
# Name: Dusknoir (Shadow), Stats: {'Attack': '119.8', 'Defense': '172.9', 'Stamina': '90', 'Overall': '1864'}, Fast Moves: ['Hex', 'Astonish'], Charged Moves: ['Shadow Punch', 'Dynamic Punch', 'Dark Pulse', 'Shadow Ball*', 'Psychic', 'Poltergeist', 'Ominous Wind', 'Frustration†'], Recommended Fast: Astonish, Recommended Charged: ['Shadow Punch', 'Dynamic Punch']
# Name: Dusknoir (Shadow), Stats: {'Attack': '119.8', 'Defense': '172.9', 'Stamina': '90', 'Overall': '1864'}, Fast Moves: ['Hex', 'Astonish'], Charged Moves: ['Shadow Punch', 'Dynamic Punch', 'Dark Pulse', 'Shadow Ball*', 'Psychic', 'Poltergeist', 'Ominous Wind', 'Frustration†'], Recommended Fast: Astonish, Recommended Charged: ['Shadow Punch', 'Dynamic Punch']
# Name: Golisopod, Stats: {'Attack': '125.1', 'Defense': '133.5', 'Stamina': '107', 'Overall': '1789'}, Fast Moves: ['Fury Cutter', 'Shadow Claw', 'Waterfall', 'Metal Claw'], Charged Moves: ['Aqua Jet', 'X-Scissor', 'Razor Shell', 'Aerial Ace', 'Liquidation'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aqua Jet', 'X-Scissor']
# Name: Golisopod, Stats: {'Attack': '125.1', 'Defense': '133.5', 'Stamina': '107', 'Overall': '1789'}, Fast Moves: ['Fury Cutter', 'Shadow Claw', 'Waterfall', 'Metal Claw'], Charged Moves: ['Aqua Jet', 'X-Scissor', 'Razor Shell', 'Aerial Ace', 'Liquidation'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aqua Jet', 'X-Scissor']
# Name: Mandibuzz, Stats: {'Attack': '92.3', 'Defense': '149.2', 'Stamina': '176', 'Overall': '2425'}, Fast Moves: ['Snarl', 'Air Slash'], Charged Moves: ['Foul Play', 'Aerial Ace', 'Shadow Ball', 'Dark Pulse'], Recommended Fast: Snarl, Recommended Charged: ['Aerial Ace', 'Dark Pulse']
# Name: Mandibuzz, Stats: {'Attack': '92.3', 'Defense': '149.2', 'Stamina': '176', 'Overall': '2425'}, Fast Moves: ['Snarl', 'Air Slash'], Charged Moves: ['Foul Play', 'Aerial Ace', 'Shadow Ball', 'Dark Pulse'], Recommended Fast: Snarl, Recommended Charged: ['Aerial Ace', 'Dark Pulse']
# Name: Corviknight, Stats: {'Attack': '107.6', 'Defense': '128.1', 'Stamina': '151', 'Overall': '2082'}, Fast Moves: ['Sand Attack', 'Steel Wing', 'Air Slash'], Charged Moves: ['Sky Attack', 'Iron Head*', 'Payback'], Recommended Fast: Sand Attack, Recommended Charged: ['Sky Attack', 'Iron Head*']
# Name: Corviknight, Stats: {'Attack': '107.6', 'Defense': '128.1', 'Stamina': '151', 'Overall': '2082'}, Fast Moves: ['Sand Attack', 'Steel Wing', 'Air Slash'], Charged Moves: ['Sky Attack', 'Iron Head*', 'Payback'], Recommended Fast: Sand Attack, Recommended Charged: ['Sky Attack', 'Iron Head*']
# Name: Gastrodon, Stats: {'Attack': '114.3', 'Defense': '102.4', 'Stamina': '167', 'Overall': '1958'}, Fast Moves: ['Mud Slap', 'Hidden Power (Ground)', 'Hidden Power (Water)', 'Hidden Power (Ice)', 'Hidden Power (Rock)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Dark)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)'], Charged Moves: ['Body Slam', 'Earth Power', 'Water Pulse', 'Earthquake'], Recommended Fast: Mud Slap, Recommended Charged: ['Body Slam', 'Earth Power']
# Name: Gastrodon, Stats: {'Attack': '114.3', 'Defense': '102.4', 'Stamina': '167', 'Overall': '1958'}, Fast Moves: ['Mud Slap', 'Hidden Power (Ground)', 'Hidden Power (Water)', 'Hidden Power (Ice)', 'Hidden Power (Rock)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Dark)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)'], Charged Moves: ['Body Slam', 'Earth Power', 'Water Pulse', 'Earthquake'], Recommended Fast: Mud Slap, Recommended Charged: ['Body Slam', 'Earth Power']
# Name: Sableye (Shadow), Stats: {'Attack': '121', 'Defense': '123.4', 'Stamina': '124', 'Overall': '1853'}, Fast Moves: ['Shadow Claw', 'Feint Attack'], Charged Moves: ['Foul Play', 'Power Gem', 'Dazzling Gleam', 'Shadow Sneak', 'Frustration†'], Recommended Fast: Shadow Claw, Recommended Charged: ['Foul Play', 'Power Gem']
# Name: Sableye (Shadow), Stats: {'Attack': '121', 'Defense': '123.4', 'Stamina': '124', 'Overall': '1853'}, Fast Moves: ['Shadow Claw', 'Feint Attack'], Charged Moves: ['Foul Play', 'Power Gem', 'Dazzling Gleam', 'Shadow Sneak', 'Frustration†'], Recommended Fast: Shadow Claw, Recommended Charged: ['Foul Play', 'Power Gem']
# Name: Steelix, Stats: {'Attack': '98.4', 'Defense': '185.2', 'Stamina': '124', 'Overall': '2261'}, Fast Moves: ['Dragon Tail', 'Thunder Fang', 'Iron Tail'], Charged Moves: ['Breaking Swipe', 'Psychic Fangs', 'Crunch', 'Earthquake', 'Heavy Slam', 'Return†'], Recommended Fast: Thunder Fang, Recommended Charged: ['Breaking Swipe', 'Psychic Fangs']
# Name: Steelix, Stats: {'Attack': '98.4', 'Defense': '185.2', 'Stamina': '124', 'Overall': '2261'}, Fast Moves: ['Dragon Tail', 'Thunder Fang', 'Iron Tail'], Charged Moves: ['Breaking Swipe', 'Psychic Fangs', 'Crunch', 'Earthquake', 'Heavy Slam', 'Return†'], Recommended Fast: Thunder Fang, Recommended Charged: ['Breaking Swipe', 'Psychic Fangs']
# Name: Stunfisk, Stats: {'Attack': '101.7', 'Defense': '127.9', 'Stamina': '169', 'Overall': '2200'}, Fast Moves: ['Thunder Shock', 'Mud Shot'], Charged Moves: ['Mud Bomb', 'Discharge', 'Muddy Water'], Recommended Fast: Thunder Shock, Recommended Charged: ['Mud Bomb', 'Discharge']
# Name: Stunfisk, Stats: {'Attack': '101.7', 'Defense': '127.9', 'Stamina': '169', 'Overall': '2200'}, Fast Moves: ['Thunder Shock', 'Mud Shot'], Charged Moves: ['Mud Bomb', 'Discharge', 'Muddy Water'], Recommended Fast: Thunder Shock, Recommended Charged: ['Mud Bomb', 'Discharge']
# Name: Dusknoir, Stats: {'Attack': '119.8', 'Defense': '172.9', 'Stamina': '90', 'Overall': '1864'}, Fast Moves: ['Hex', 'Astonish'], Charged Moves: ['Shadow Punch', 'Dynamic Punch', 'Dark Pulse', 'Shadow Ball*', 'Psychic', 'Return†', 'Poltergeist', 'Ominous Wind'], Recommended Fast: Astonish, Recommended Charged: ['Shadow Punch', 'Dynamic Punch']
# Name: Dusknoir, Stats: {'Attack': '119.8', 'Defense': '172.9', 'Stamina': '90', 'Overall': '1864'}, Fast Moves: ['Hex', 'Astonish'], Charged Moves: ['Shadow Punch', 'Dynamic Punch', 'Dark Pulse', 'Shadow Ball*', 'Psychic', 'Return†', 'Poltergeist', 'Ominous Wind'], Recommended Fast: Astonish, Recommended Charged: ['Shadow Punch', 'Dynamic Punch']
# Name: Feraligatr (Shadow), Stats: {'Attack': '123.2', 'Defense': '117.9', 'Stamina': '124', 'Overall': '1804'}, Fast Moves: ['Shadow Claw', 'Ice Fang', 'Water Gun*', 'Waterfall', 'Bite'], Charged Moves: ['Hydro Cannon*', 'Crunch', 'Ice Beam', 'Hydro Pump', 'Frustration†'], Recommended Fast: Shadow Claw, Recommended Charged: ['Hydro Cannon*', 'Ice Beam']
# Name: Feraligatr (Shadow), Stats: {'Attack': '123.2', 'Defense': '117.9', 'Stamina': '124', 'Overall': '1804'}, Fast Moves: ['Shadow Claw', 'Ice Fang', 'Water Gun*', 'Waterfall', 'Bite'], Charged Moves: ['Hydro Cannon*', 'Crunch', 'Ice Beam', 'Hydro Pump', 'Frustration†'], Recommended Fast: Shadow Claw, Recommended Charged: ['Hydro Cannon*', 'Ice Beam']
# Name: Samurott (Shadow), Stats: {'Attack': '129', 'Defense': '102.1', 'Stamina': '132', 'Overall': '1740'}, Fast Moves: ['Fury Cutter', 'Waterfall'], Charged Moves: ['Hydro Cannon*', 'Razor Shell', 'Megahorn', 'Liquidation', 'Blizzard', 'Hydro Pump', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Hydro Cannon*', 'Megahorn']
# Name: Samurott (Shadow), Stats: {'Attack': '129', 'Defense': '102.1', 'Stamina': '132', 'Overall': '1740'}, Fast Moves: ['Fury Cutter', 'Waterfall'], Charged Moves: ['Hydro Cannon*', 'Razor Shell', 'Megahorn', 'Liquidation', 'Blizzard', 'Hydro Pump', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Hydro Cannon*', 'Megahorn']
# Name: Annihilape (Shadow), Stats: {'Attack': '123.9', 'Defense': '106.3', 'Stamina': '137', 'Overall': '1805'}, Fast Moves: ['Counter', 'Low Kick'], Charged Moves: ['Rage Fist*', 'Close Combat', 'Ice Punch', 'Night Slash', 'Low Sweep', 'Shadow Ball', 'Frustration†'], Recommended Fast: Counter, Recommended Charged: ['Rage Fist*', 'Ice Punch']
# Name: Annihilape (Shadow), Stats: {'Attack': '123.9', 'Defense': '106.3', 'Stamina': '137', 'Overall': '1805'}, Fast Moves: ['Counter', 'Low Kick'], Charged Moves: ['Rage Fist*', 'Close Combat', 'Ice Punch', 'Night Slash', 'Low Sweep', 'Shadow Ball', 'Frustration†'], Recommended Fast: Counter, Recommended Charged: ['Rage Fist*', 'Ice Punch']
# Name: Metang (Shadow), Stats: {'Attack': '108.9', 'Defense': '145.4', 'Stamina': '129', 'Overall': '2043'}, Fast Moves: ['Fury Cutter', 'Metal Claw', 'Zen Headbutt'], Charged Moves: ['Psyshock', 'Gyro Ball', 'Psychic', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Psyshock', 'Gyro Ball']
# Name: Metang (Shadow), Stats: {'Attack': '108.9', 'Defense': '145.4', 'Stamina': '129', 'Overall': '2043'}, Fast Moves: ['Fury Cutter', 'Metal Claw', 'Zen Headbutt'], Charged Moves: ['Psyshock', 'Gyro Ball', 'Psychic', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Psyshock', 'Gyro Ball']
# Name: Diggersby (Shadow), Stats: {'Attack': '96.3', 'Defense': '141.1', 'Stamina': '171', 'Overall': '2325'}, Fast Moves: ['Quick Attack', 'Mud Shot'], Charged Moves: ['Scorching Sands', 'Fire Punch', 'Hyper Beam', 'Dig', 'Earthquake', 'Frustration†'], Recommended Fast: Quick Attack, Recommended Charged: ['Scorching Sands', 'Fire Punch']
# Name: Diggersby (Shadow), Stats: {'Attack': '96.3', 'Defense': '141.1', 'Stamina': '171', 'Overall': '2325'}, Fast Moves: ['Quick Attack', 'Mud Shot'], Charged Moves: ['Scorching Sands', 'Fire Punch', 'Hyper Beam', 'Dig', 'Earthquake', 'Frustration†'], Recommended Fast: Quick Attack, Recommended Charged: ['Scorching Sands', 'Fire Punch']
# Name: Carbink, Stats: {'Attack': '84.8', 'Defense': '247.8', 'Stamina': '126', 'Overall': '2651'}, Fast Moves: ['Rock Throw', 'Tackle'], Charged Moves: ['Power Gem', 'Rock Slide', 'Moonblast'], Recommended Fast: Rock Throw, Recommended Charged: ['Power Gem', 'Moonblast']
# Name: Carbink, Stats: {'Attack': '84.8', 'Defense': '247.8', 'Stamina': '126', 'Overall': '2651'}, Fast Moves: ['Rock Throw', 'Tackle'], Charged Moves: ['Power Gem', 'Rock Slide', 'Moonblast'], Recommended Fast: Rock Throw, Recommended Charged: ['Power Gem', 'Moonblast']
# Name: Dedenne, Stats: {'Attack': '124.1', 'Defense': '108.7', 'Stamina': '133', 'Overall': '1796'}, Fast Moves: ['Thunder Shock', 'Tackle'], Charged Moves: ['Parabolic Charge', 'Discharge', 'Play Rough'], Recommended Fast: Thunder Shock, Recommended Charged: ['Parabolic Charge', 'Play Rough']
# Name: Dedenne, Stats: {'Attack': '124.1', 'Defense': '108.7', 'Stamina': '133', 'Overall': '1796'}, Fast Moves: ['Thunder Shock', 'Tackle'], Charged Moves: ['Parabolic Charge', 'Discharge', 'Play Rough'], Recommended Fast: Thunder Shock, Recommended Charged: ['Parabolic Charge', 'Play Rough']
# Name: Marowak (Shadow), Stats: {'Attack': '110.8', 'Defense': '145', 'Stamina': '126', 'Overall': '2025'}, Fast Moves: ['Mud Slap', 'Rock Smash'], Charged Moves: ['Bone Club', 'Rock Slide', 'Dig', 'Earthquake', 'Frustration†'], Recommended Fast: Mud Slap, Recommended Charged: ['Bone Club', 'Rock Slide']
# Name: Marowak (Shadow), Stats: {'Attack': '110.8', 'Defense': '145', 'Stamina': '126', 'Overall': '2025'}, Fast Moves: ['Mud Slap', 'Rock Smash'], Charged Moves: ['Bone Club', 'Rock Slide', 'Dig', 'Earthquake', 'Frustration†'], Recommended Fast: Mud Slap, Recommended Charged: ['Bone Club', 'Rock Slide']
# Name: Morpeko (Full Belly), Stats: {'Attack': '141.7', 'Defense': '97.8', 'Stamina': '114', 'Overall': '1581'}, Fast Moves: ['Thunder Shock', 'Charge Beam', 'Bite'], Charged Moves: ['Aura Wheel', 'Psychic Fangs', 'Seed Bomb', 'Outrage'], Recommended Fast: Thunder Shock, Recommended Charged: ['Aura Wheel', 'Psychic Fangs']
# Name: Morpeko (Full Belly), Stats: {'Attack': '141.7', 'Defense': '97.8', 'Stamina': '114', 'Overall': '1581'}, Fast Moves: ['Thunder Shock', 'Charge Beam', 'Bite'], Charged Moves: ['Aura Wheel', 'Psychic Fangs', 'Seed Bomb', 'Outrage'], Recommended Fast: Thunder Shock, Recommended Charged: ['Aura Wheel', 'Psychic Fangs']
# Name: Weezing (Galarian) (Shadow), Stats: {'Attack': '118.3', 'Defense': '138.8', 'Stamina': '115', 'Overall': '1890'}, Fast Moves: ['Fairy Wind', 'Tackle'], Charged Moves: ['Sludge', 'Brutal Swing', 'Play Rough', 'Overheat', 'Hyper Beam', 'Frustration†'], Recommended Fast: Fairy Wind, Recommended Charged: ['Sludge', 'Brutal Swing']
# Name: Weezing (Galarian) (Shadow), Stats: {'Attack': '118.3', 'Defense': '138.8', 'Stamina': '115', 'Overall': '1890'}, Fast Moves: ['Fairy Wind', 'Tackle'], Charged Moves: ['Sludge', 'Brutal Swing', 'Play Rough', 'Overheat', 'Hyper Beam', 'Frustration†'], Recommended Fast: Fairy Wind, Recommended Charged: ['Sludge', 'Brutal Swing']
# Name: Golurk (Shadow), Stats: {'Attack': '133.9', 'Defense': '96.7', 'Stamina': '129', 'Overall': '1671'}, Fast Moves: ['Mud Slap', 'Astonish'], Charged Moves: ['Shadow Punch', 'Dynamic Punch', 'Earth Power', 'Poltergeist', 'Frustration†'], Recommended Fast: Mud Slap, Recommended Charged: ['Shadow Punch', 'Dynamic Punch']
# Name: Golurk (Shadow), Stats: {'Attack': '133.9', 'Defense': '96.7', 'Stamina': '129', 'Overall': '1671'}, Fast Moves: ['Mud Slap', 'Astonish'], Charged Moves: ['Shadow Punch', 'Dynamic Punch', 'Earth Power', 'Poltergeist', 'Frustration†'], Recommended Fast: Mud Slap, Recommended Charged: ['Shadow Punch', 'Dynamic Punch']
# Name: Quagsire (Shadow), Stats: {'Attack': '111.2', 'Defense': '111.9', 'Stamina': '161', 'Overall': '2006'}, Fast Moves: ['Mud Shot', 'Water Gun'], Charged Moves: ['Aqua Tail*', 'Mud Bomb', 'Stone Edge', 'Sludge Bomb', 'Earthquake', 'Acid Spray', 'Frustration†'], Recommended Fast: Mud Shot, Recommended Charged: ['Aqua Tail*', 'Stone Edge']
# Name: Quagsire (Shadow), Stats: {'Attack': '111.2', 'Defense': '111.9', 'Stamina': '161', 'Overall': '2006'}, Fast Moves: ['Mud Shot', 'Water Gun'], Charged Moves: ['Aqua Tail*', 'Mud Bomb', 'Stone Edge', 'Sludge Bomb', 'Earthquake', 'Acid Spray', 'Frustration†'], Recommended Fast: Mud Shot, Recommended Charged: ['Aqua Tail*', 'Stone Edge']
# Name: Machoke (Shadow), Stats: {'Attack': '127.7', 'Defense': '97.1', 'Stamina': '141', 'Overall': '1750'}, Fast Moves: ['Karate Chop', 'Low Kick'], Charged Moves: ['Cross Chop*', 'Dynamic Punch', 'Brick Break', 'Submission', 'Frustration†'], Recommended Fast: Karate Chop, Recommended Charged: ['Cross Chop*', 'Dynamic Punch']
# Name: Machoke (Shadow), Stats: {'Attack': '127.7', 'Defense': '97.1', 'Stamina': '141', 'Overall': '1750'}, Fast Moves: ['Karate Chop', 'Low Kick'], Charged Moves: ['Cross Chop*', 'Dynamic Punch', 'Brick Break', 'Submission', 'Frustration†'], Recommended Fast: Karate Chop, Recommended Charged: ['Cross Chop*', 'Dynamic Punch']
# Name: Steelix (Shadow), Stats: {'Attack': '98.4', 'Defense': '185.2', 'Stamina': '124', 'Overall': '2261'}, Fast Moves: ['Dragon Tail', 'Thunder Fang', 'Iron Tail'], Charged Moves: ['Breaking Swipe', 'Psychic Fangs', 'Crunch', 'Earthquake', 'Heavy Slam', 'Frustration†'], Recommended Fast: Thunder Fang, Recommended Charged: ['Breaking Swipe', 'Psychic Fangs']
# Name: Steelix (Shadow), Stats: {'Attack': '98.4', 'Defense': '185.2', 'Stamina': '124', 'Overall': '2261'}, Fast Moves: ['Dragon Tail', 'Thunder Fang', 'Iron Tail'], Charged Moves: ['Breaking Swipe', 'Psychic Fangs', 'Crunch', 'Earthquake', 'Heavy Slam', 'Frustration†'], Recommended Fast: Thunder Fang, Recommended Charged: ['Breaking Swipe', 'Psychic Fangs']
# Name: Togedemaru, Stats: {'Attack': '132.1', 'Defense': '105.5', 'Stamina': '121', 'Overall': '1688'}, Fast Moves: ['Thunder Shock', 'Spark'], Charged Moves: ['Wild Charge', 'Gyro Ball', 'Fell Stinger'], Recommended Fast: Thunder Shock, Recommended Charged: ['Wild Charge', 'Fell Stinger']
# Name: Togedemaru, Stats: {'Attack': '132.1', 'Defense': '105.5', 'Stamina': '121', 'Overall': '1688'}, Fast Moves: ['Thunder Shock', 'Spark'], Charged Moves: ['Wild Charge', 'Gyro Ball', 'Fell Stinger'], Recommended Fast: Thunder Shock, Recommended Charged: ['Wild Charge', 'Fell Stinger']
# Name: Cradily, Stats: {'Attack': '106.2', 'Defense': '138.9', 'Stamina': '143', 'Overall': '2112'}, Fast Moves: ['Acid', 'Bullet Seed', 'Infestation'], Charged Moves: ['Rock Tomb', 'Grass Knot', 'Rock Slide', 'Bulldoze', 'Stone Edge', 'Return†'], Recommended Fast: Acid, Recommended Charged: ['Rock Tomb', 'Grass Knot']
# Name: Cradily, Stats: {'Attack': '106.2', 'Defense': '138.9', 'Stamina': '143', 'Overall': '2112'}, Fast Moves: ['Acid', 'Bullet Seed', 'Infestation'], Charged Moves: ['Rock Tomb', 'Grass Knot', 'Rock Slide', 'Bulldoze', 'Stone Edge', 'Return†'], Recommended Fast: Acid, Recommended Charged: ['Rock Tomb', 'Grass Knot']
# Name: Forretress (Shadow), Stats: {'Attack': '110.2', 'Defense': '141.6', 'Stamina': '130', 'Overall': '2029'}, Fast Moves: ['Volt Switch', 'Bug Bite', 'Struggle Bug'], Charged Moves: ['Rock Tomb', 'Mirror Shot', 'Heavy Slam', 'Earthquake', 'Sand Tomb', 'Frustration†'], Recommended Fast: Bug Bite, Recommended Charged: ['Rock Tomb', 'Sand Tomb']
# Name: Forretress (Shadow), Stats: {'Attack': '110.2', 'Defense': '141.6', 'Stamina': '130', 'Overall': '2029'}, Fast Moves: ['Volt Switch', 'Bug Bite', 'Struggle Bug'], Charged Moves: ['Rock Tomb', 'Mirror Shot', 'Heavy Slam', 'Earthquake', 'Sand Tomb', 'Frustration†'], Recommended Fast: Bug Bite, Recommended Charged: ['Rock Tomb', 'Sand Tomb']
# Name: Lapras (Shadow), Stats: {'Attack': '104.6', 'Defense': '113.9', 'Stamina': '179', 'Overall': '2136'}, Fast Moves: ['Psywave', 'Ice Shard*', 'Water Gun', 'Frost Breath'], Charged Moves: ['Sparkling Aria', 'Ice Beam*', 'Surf', 'Skull Bash', 'Dragon Pulse*', 'Blizzard', 'Hydro Pump', 'Frustration†'], Recommended Fast: Psywave, Recommended Charged: ['Sparkling Aria', 'Ice Beam*']
# Name: Lapras (Shadow), Stats: {'Attack': '104.6', 'Defense': '113.9', 'Stamina': '179', 'Overall': '2136'}, Fast Moves: ['Psywave', 'Ice Shard*', 'Water Gun', 'Frost Breath'], Charged Moves: ['Sparkling Aria', 'Ice Beam*', 'Surf', 'Skull Bash', 'Dragon Pulse*', 'Blizzard', 'Hydro Pump', 'Frustration†'], Recommended Fast: Psywave, Recommended Charged: ['Sparkling Aria', 'Ice Beam*']
# Name: Marowak, Stats: {'Attack': '110.8', 'Defense': '145', 'Stamina': '126', 'Overall': '2025'}, Fast Moves: ['Mud Slap', 'Rock Smash'], Charged Moves: ['Bone Club', 'Rock Slide', 'Return†', 'Dig', 'Earthquake'], Recommended Fast: Mud Slap, Recommended Charged: ['Bone Club', 'Rock Slide']
# Name: Marowak, Stats: {'Attack': '110.8', 'Defense': '145', 'Stamina': '126', 'Overall': '2025'}, Fast Moves: ['Mud Slap', 'Rock Smash'], Charged Moves: ['Bone Club', 'Rock Slide', 'Return†', 'Dig', 'Earthquake'], Recommended Fast: Mud Slap, Recommended Charged: ['Bone Club', 'Rock Slide']
# Name: Primeape, Stats: {'Attack': '140.1', 'Defense': '99.1', 'Stamina': '115', 'Overall': '1599'}, Fast Moves: ['Karate Chop*', 'Counter', 'Low Kick'], Charged Moves: ['Close Combat', 'Rage Fist*', 'Cross Chop*', 'Night Slash', 'Ice Punch', 'Return†', 'Low Sweep'], Recommended Fast: Karate Chop*, Recommended Charged: ['Close Combat', 'Rage Fist*']
# Name: Primeape, Stats: {'Attack': '140.1', 'Defense': '99.1', 'Stamina': '115', 'Overall': '1599'}, Fast Moves: ['Karate Chop*', 'Counter', 'Low Kick'], Charged Moves: ['Close Combat', 'Rage Fist*', 'Cross Chop*', 'Night Slash', 'Ice Punch', 'Return†', 'Low Sweep'], Recommended Fast: Karate Chop*, Recommended Charged: ['Close Combat', 'Rage Fist*']
# Name: Furret, Stats: {'Attack': '116', 'Defense': '105.4', 'Stamina': '158', 'Overall': '1934'}, Fast Moves: ['Sucker Punch', 'Quick Attack'], Charged Moves: ['Swift', 'Trailblaze', 'Brick Break', 'Dig', 'Hyper Beam'], Recommended Fast: Sucker Punch, Recommended Charged: ['Swift', 'Trailblaze']
# Name: Furret, Stats: {'Attack': '116', 'Defense': '105.4', 'Stamina': '158', 'Overall': '1934'}, Fast Moves: ['Sucker Punch', 'Quick Attack'], Charged Moves: ['Swift', 'Trailblaze', 'Brick Break', 'Dig', 'Hyper Beam'], Recommended Fast: Sucker Punch, Recommended Charged: ['Swift', 'Trailblaze']
# Name: Pangoro, Stats: {'Attack': '134.5', 'Defense': '92', 'Stamina': '134', 'Overall': '1658'}, Fast Moves: ['Karate Chop', 'Snarl', 'Bullet Punch', 'Low Kick'], Charged Moves: ['Close Combat', 'Night Slash', 'Rock Slide', 'Iron Head'], Recommended Fast: Karate Chop, Recommended Charged: ['Close Combat', 'Night Slash']
# Name: Pangoro, Stats: {'Attack': '134.5', 'Defense': '92', 'Stamina': '134', 'Overall': '1658'}, Fast Moves: ['Karate Chop', 'Snarl', 'Bullet Punch', 'Low Kick'], Charged Moves: ['Close Combat', 'Night Slash', 'Rock Slide', 'Iron Head'], Recommended Fast: Karate Chop, Recommended Charged: ['Close Combat', 'Night Slash']
# Name: Bastiodon, Stats: {'Attack': '81.1', 'Defense': '246.6', 'Stamina': '138', 'Overall': '2762'}, Fast Moves: ['Smack Down', 'Iron Tail'], Charged Moves: ['Stone Edge', 'Flamethrower', 'Flash Cannon', 'Return†'], Recommended Fast: Smack Down, Recommended Charged: ['Stone Edge', 'Flamethrower']
# Name: Bastiodon, Stats: {'Attack': '81.1', 'Defense': '246.6', 'Stamina': '138', 'Overall': '2762'}, Fast Moves: ['Smack Down', 'Iron Tail'], Charged Moves: ['Stone Edge', 'Flamethrower', 'Flash Cannon', 'Return†'], Recommended Fast: Smack Down, Recommended Charged: ['Stone Edge', 'Flamethrower']
# Name: Dusclops (Shadow), Stats: {'Attack': '103', 'Defense': '198.9', 'Stamina': '106', 'Overall': '2173'}, Fast Moves: ['Hex', 'Feint Attack'], Charged Moves: ['Shadow Punch', 'Ice Punch', 'Fire Punch', 'Poltergeist', 'Frustration†'], Recommended Fast: Hex, Recommended Charged: ['Shadow Punch', 'Ice Punch']
# Name: Dusclops (Shadow), Stats: {'Attack': '103', 'Defense': '198.9', 'Stamina': '106', 'Overall': '2173'}, Fast Moves: ['Hex', 'Feint Attack'], Charged Moves: ['Shadow Punch', 'Ice Punch', 'Fire Punch', 'Poltergeist', 'Frustration†'], Recommended Fast: Hex, Recommended Charged: ['Shadow Punch', 'Ice Punch']
# Name: Emolga, Stats: {'Attack': '127.8', 'Defense': '111.4', 'Stamina': '123', 'Overall': '1753'}, Fast Moves: ['Thunder Shock', 'Quick Attack'], Charged Moves: ['Acrobatics', 'Aerial Ace', 'Discharge', 'Thunderbolt'], Recommended Fast: Thunder Shock, Recommended Charged: ['Acrobatics', 'Discharge']
# Name: Emolga, Stats: {'Attack': '127.8', 'Defense': '111.4', 'Stamina': '123', 'Overall': '1753'}, Fast Moves: ['Thunder Shock', 'Quick Attack'], Charged Moves: ['Acrobatics', 'Aerial Ace', 'Discharge', 'Thunderbolt'], Recommended Fast: Thunder Shock, Recommended Charged: ['Acrobatics', 'Discharge']
# Name: Runerigus, Stats: {'Attack': '112.2', 'Defense': '168.3', 'Stamina': '106', 'Overall': '2002'}, Fast Moves: ['Shadow Claw', 'Astonish'], Charged Moves: ['Brutal Swing', 'Rock Tomb', 'Shadow Ball', 'Sand Tomb'], Recommended Fast: Shadow Claw, Recommended Charged: ['Rock Tomb', 'Shadow Ball']
# Name: Runerigus, Stats: {'Attack': '112.2', 'Defense': '168.3', 'Stamina': '106', 'Overall': '2002'}, Fast Moves: ['Shadow Claw', 'Astonish'], Charged Moves: ['Brutal Swing', 'Rock Tomb', 'Shadow Ball', 'Sand Tomb'], Recommended Fast: Shadow Claw, Recommended Charged: ['Rock Tomb', 'Shadow Ball']
# Name: Azumarill, Stats: {'Attack': '93.7', 'Defense': '134', 'Stamina': '190', 'Overall': '2387'}, Fast Moves: ['Bubble', 'Rock Smash'], Charged Moves: ['Ice Beam', 'Play Rough', 'Hydro Pump'], Recommended Fast: Bubble, Recommended Charged: ['Ice Beam', 'Play Rough']
# Name: Azumarill, Stats: {'Attack': '93.7', 'Defense': '134', 'Stamina': '190', 'Overall': '2387'}, Fast Moves: ['Bubble', 'Rock Smash'], Charged Moves: ['Ice Beam', 'Play Rough', 'Hydro Pump'], Recommended Fast: Bubble, Recommended Charged: ['Ice Beam', 'Play Rough']
# Name: Malamar (Shadow), Stats: {'Attack': '118.4', 'Defense': '117.1', 'Stamina': '136', 'Overall': '1887'}, Fast Moves: ['Psywave', 'Psycho Cut', 'Peck'], Charged Moves: ['Foul Play', 'Superpower', 'Psybeam', 'Hyper Beam', 'Frustration†'], Recommended Fast: Psywave, Recommended Charged: ['Foul Play', 'Superpower']
# Name: Malamar (Shadow), Stats: {'Attack': '118.4', 'Defense': '117.1', 'Stamina': '136', 'Overall': '1887'}, Fast Moves: ['Psywave', 'Psycho Cut', 'Peck'], Charged Moves: ['Foul Play', 'Superpower', 'Psybeam', 'Hyper Beam', 'Frustration†'], Recommended Fast: Psywave, Recommended Charged: ['Foul Play', 'Superpower']
# Name: Primeape (Shadow), Stats: {'Attack': '140.1', 'Defense': '99.1', 'Stamina': '115', 'Overall': '1599'}, Fast Moves: ['Karate Chop*', 'Counter', 'Low Kick'], Charged Moves: ['Close Combat', 'Rage Fist*', 'Cross Chop*', 'Night Slash', 'Ice Punch', 'Low Sweep', 'Frustration†'], Recommended Fast: Karate Chop*, Recommended Charged: ['Close Combat', 'Rage Fist*']
# Name: Primeape (Shadow), Stats: {'Attack': '140.1', 'Defense': '99.1', 'Stamina': '115', 'Overall': '1599'}, Fast Moves: ['Karate Chop*', 'Counter', 'Low Kick'], Charged Moves: ['Close Combat', 'Rage Fist*', 'Cross Chop*', 'Night Slash', 'Ice Punch', 'Low Sweep', 'Frustration†'], Recommended Fast: Karate Chop*, Recommended Charged: ['Close Combat', 'Rage Fist*']
# Name: Grumpig, Stats: {'Attack': '114.5', 'Defense': '128.2', 'Stamina': '133', 'Overall': '1954'}, Fast Moves: ['Psywave', 'Extrasensory', 'Charge Beam'], Charged Moves: ['Dynamic Punch', 'Shadow Ball', 'Psychic', 'Return†', 'Mirror Coat'], Recommended Fast: Psywave, Recommended Charged: ['Dynamic Punch', 'Shadow Ball']
# Name: Grumpig, Stats: {'Attack': '114.5', 'Defense': '128.2', 'Stamina': '133', 'Overall': '1954'}, Fast Moves: ['Psywave', 'Extrasensory', 'Charge Beam'], Charged Moves: ['Dynamic Punch', 'Shadow Ball', 'Psychic', 'Return†', 'Mirror Coat'], Recommended Fast: Psywave, Recommended Charged: ['Dynamic Punch', 'Shadow Ball']
# Name: Quagsire, Stats: {'Attack': '111.2', 'Defense': '111.9', 'Stamina': '161', 'Overall': '2006'}, Fast Moves: ['Mud Shot', 'Water Gun'], Charged Moves: ['Aqua Tail*', 'Mud Bomb', 'Stone Edge', 'Sludge Bomb', 'Return†', 'Earthquake', 'Acid Spray'], Recommended Fast: Mud Shot, Recommended Charged: ['Aqua Tail*', 'Stone Edge']
# Name: Quagsire, Stats: {'Attack': '111.2', 'Defense': '111.9', 'Stamina': '161', 'Overall': '2006'}, Fast Moves: ['Mud Shot', 'Water Gun'], Charged Moves: ['Aqua Tail*', 'Mud Bomb', 'Stone Edge', 'Sludge Bomb', 'Return†', 'Earthquake', 'Acid Spray'], Recommended Fast: Mud Shot, Recommended Charged: ['Aqua Tail*', 'Stone Edge']
# Name: Sableye, Stats: {'Attack': '121', 'Defense': '123.4', 'Stamina': '124', 'Overall': '1853'}, Fast Moves: ['Shadow Claw', 'Feint Attack'], Charged Moves: ['Foul Play', 'Power Gem', 'Dazzling Gleam', 'Shadow Sneak', 'Return†'], Recommended Fast: Shadow Claw, Recommended Charged: ['Foul Play', 'Power Gem']
# Name: Sableye, Stats: {'Attack': '121', 'Defense': '123.4', 'Stamina': '124', 'Overall': '1853'}, Fast Moves: ['Shadow Claw', 'Feint Attack'], Charged Moves: ['Foul Play', 'Power Gem', 'Dazzling Gleam', 'Shadow Sneak', 'Return†'], Recommended Fast: Shadow Claw, Recommended Charged: ['Foul Play', 'Power Gem']
# Name: Bellibolt, Stats: {'Attack': '115', 'Defense': '107.7', 'Stamina': '156', 'Overall': '1934'}, Fast Moves: ['Thunder Shock', 'Sucker Punch', 'Water Gun'], Charged Moves: ['Parabolic Charge', 'Discharge', 'Zap Cannon'], Recommended Fast: Sucker Punch, Recommended Charged: ['Parabolic Charge', 'Zap Cannon']
# Name: Bellibolt, Stats: {'Attack': '115', 'Defense': '107.7', 'Stamina': '156', 'Overall': '1934'}, Fast Moves: ['Thunder Shock', 'Sucker Punch', 'Water Gun'], Charged Moves: ['Parabolic Charge', 'Discharge', 'Zap Cannon'], Recommended Fast: Sucker Punch, Recommended Charged: ['Parabolic Charge', 'Zap Cannon']
# Name: Dewott (Shadow), Stats: {'Attack': '124.2', 'Defense': '98.6', 'Stamina': '147', 'Overall': '1800'}, Fast Moves: ['Fury Cutter', 'Water Gun'], Charged Moves: ['Aqua Tail', 'X-Scissor', 'Water Pulse', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aqua Tail', 'X-Scissor']
# Name: Dewott (Shadow), Stats: {'Attack': '124.2', 'Defense': '98.6', 'Stamina': '147', 'Overall': '1800'}, Fast Moves: ['Fury Cutter', 'Water Gun'], Charged Moves: ['Aqua Tail', 'X-Scissor', 'Water Pulse', 'Frustration†'], Recommended Fast: Fury Cutter, Recommended Charged: ['Aqua Tail', 'X-Scissor']
# Name: Dragalge, Stats: {'Attack': '117.8', 'Defense': '139.8', 'Stamina': '115', 'Overall': '1896'}, Fast Moves: ['Acid', 'Dragon Tail', 'Water Gun'], Charged Moves: ['Aqua Tail', 'Sludge Bomb', 'Outrage', 'Focus Blast', 'Gunk Shot', 'Hydro Pump'], Recommended Fast: Acid, Recommended Charged: ['Aqua Tail', 'Outrage']
# Name: Dragalge, Stats: {'Attack': '117.8', 'Defense': '139.8', 'Stamina': '115', 'Overall': '1896'}, Fast Moves: ['Acid', 'Dragon Tail', 'Water Gun'], Charged Moves: ['Aqua Tail', 'Sludge Bomb', 'Outrage', 'Focus Blast', 'Gunk Shot', 'Hydro Pump'], Recommended Fast: Acid, Recommended Charged: ['Aqua Tail', 'Outrage']
# Name: Malamar, Stats: {'Attack': '118.4', 'Defense': '117.1', 'Stamina': '136', 'Overall': '1887'}, Fast Moves: ['Psywave', 'Psycho Cut', 'Peck'], Charged Moves: ['Foul Play', 'Superpower', 'Psybeam', 'Return†', 'Hyper Beam'], Recommended Fast: Psywave, Recommended Charged: ['Foul Play', 'Superpower']
# Name: Malamar, Stats: {'Attack': '118.4', 'Defense': '117.1', 'Stamina': '136', 'Overall': '1887'}, Fast Moves: ['Psywave', 'Psycho Cut', 'Peck'], Charged Moves: ['Foul Play', 'Superpower', 'Psybeam', 'Return†', 'Hyper Beam'], Recommended Fast: Psywave, Recommended Charged: ['Foul Play', 'Superpower']
# Name: Araquanid, Stats: {'Attack': '97.8', 'Defense': '176.1', 'Stamina': '133', 'Overall': '2292'}, Fast Moves: ['Bug Bite', 'Infestation'], Charged Moves: ['Bug Buzz', 'Water Pulse', 'Bubble Beam', 'Mirror Coat'], Recommended Fast: Bug Bite, Recommended Charged: ['Water Pulse', 'Bubble Beam']
# Name: Araquanid, Stats: {'Attack': '97.8', 'Defense': '176.1', 'Stamina': '133', 'Overall': '2292'}, Fast Moves: ['Bug Bite', 'Infestation'], Charged Moves: ['Bug Buzz', 'Water Pulse', 'Bubble Beam', 'Mirror Coat'], Recommended Fast: Bug Bite, Recommended Charged: ['Water Pulse', 'Bubble Beam']
# Name: Claydol, Stats: {'Attack': '102.6', 'Defense': '173.3', 'Stamina': '121', 'Overall': '2153'}, Fast Moves: ['Mud Slap', 'Confusion', 'Extrasensory'], Charged Moves: ['Rock Tomb', 'Scorching Sands', 'Ice Beam', 'Shadow Ball', 'Psychic', 'Earth Power', 'Earthquake', 'Gyro Ball'], Recommended Fast: Mud Slap, Recommended Charged: ['Rock Tomb', 'Ice Beam']
# Name: Claydol, Stats: {'Attack': '102.6', 'Defense': '173.3', 'Stamina': '121', 'Overall': '2153'}, Fast Moves: ['Mud Slap', 'Confusion', 'Extrasensory'], Charged Moves: ['Rock Tomb', 'Scorching Sands', 'Ice Beam', 'Shadow Ball', 'Psychic', 'Earth Power', 'Earthquake', 'Gyro Ball'], Recommended Fast: Mud Slap, Recommended Charged: ['Rock Tomb', 'Ice Beam']
# Name: Metang, Stats: {'Attack': '108.9', 'Defense': '145.4', 'Stamina': '129', 'Overall': '2043'}, Fast Moves: ['Fury Cutter', 'Metal Claw', 'Zen Headbutt'], Charged Moves: ['Psyshock', 'Gyro Ball', 'Return†', 'Psychic'], Recommended Fast: Fury Cutter, Recommended Charged: ['Psyshock', 'Return†']
# Name: Metang, Stats: {'Attack': '108.9', 'Defense': '145.4', 'Stamina': '129', 'Overall': '2043'}, Fast Moves: ['Fury Cutter', 'Metal Claw', 'Zen Headbutt'], Charged Moves: ['Psyshock', 'Gyro Ball', 'Return†', 'Psychic'], Recommended Fast: Fury Cutter, Recommended Charged: ['Psyshock', 'Return†']
# Name: Moltres (Galarian), Stats: {'Attack': '115.1', 'Defense': '137.4', 'Stamina': '122', 'Overall': '1931'}, Fast Moves: ['Sucker Punch', 'Wing Attack'], Charged Moves: ['Brave Bird', 'Fly', 'Payback', 'Ancient Power'], Recommended Fast: Sucker Punch, Recommended Charged: ['Brave Bird', 'Fly']
# Name: Moltres (Galarian), Stats: {'Attack': '115.1', 'Defense': '137.4', 'Stamina': '122', 'Overall': '1931'}, Fast Moves: ['Sucker Punch', 'Wing Attack'], Charged Moves: ['Brave Bird', 'Fly', 'Payback', 'Ancient Power'], Recommended Fast: Sucker Punch, Recommended Charged: ['Brave Bird', 'Fly']
# Name: Scizor (Shadow), Stats: {'Attack': '137.8', 'Defense': '110.3', 'Stamina': '106', 'Overall': '1613'}, Fast Moves: ['Fury Cutter', 'Bullet Punch'], Charged Moves: ['Night Slash', 'X-Scissor', 'Trailblaze', 'Iron Head', 'Frustration†'], Recommended Fast: Bullet Punch, Recommended Charged: ['Night Slash', 'Trailblaze']
# Name: Scizor (Shadow), Stats: {'Attack': '137.8', 'Defense': '110.3', 'Stamina': '106', 'Overall': '1613'}, Fast Moves: ['Fury Cutter', 'Bullet Punch'], Charged Moves: ['Night Slash', 'X-Scissor', 'Trailblaze', 'Iron Head', 'Frustration†'], Recommended Fast: Bullet Punch, Recommended Charged: ['Night Slash', 'Trailblaze']
# Name: Tinkaton, Stats: {'Attack': '107.2', 'Defense': '136.2', 'Stamina': '143', 'Overall': '2090'}, Fast Moves: ['Fairy Wind', 'Rock Smash'], Charged Moves: ['Heavy Slam', 'Play Rough', 'Bulldoze', 'Flash Cannon'], Recommended Fast: Fairy Wind, Recommended Charged: ['Play Rough', 'Bulldoze']
# Name: Tinkaton, Stats: {'Attack': '107.2', 'Defense': '136.2', 'Stamina': '143', 'Overall': '2090'}, Fast Moves: ['Fairy Wind', 'Rock Smash'], Charged Moves: ['Heavy Slam', 'Play Rough', 'Bulldoze', 'Flash Cannon'], Recommended Fast: Fairy Wind, Recommended Charged: ['Play Rough', 'Bulldoze']
# Name: Toxapex, Stats: {'Attack': '92.2', 'Defense': '222', 'Stamina': '118', 'Overall': '2417'}, Fast Moves: ['Poison Jab', 'Bite'], Charged Moves: ['Brine', 'Sludge Wave', 'Gunk Shot'], Recommended Fast: Poison Jab, Recommended Charged: ['Brine', 'Sludge Wave']
# Name: Toxapex, Stats: {'Attack': '92.2', 'Defense': '222', 'Stamina': '118', 'Overall': '2417'}, Fast Moves: ['Poison Jab', 'Bite'], Charged Moves: ['Brine', 'Sludge Wave', 'Gunk Shot'], Recommended Fast: Poison Jab, Recommended Charged: ['Brine', 'Sludge Wave']
# Name: Aurorus, Stats: {'Attack': '114.1', 'Defense': '105.7', 'Stamina': '163', 'Overall': '1967'}, Fast Moves: ['Powder Snow', 'Rock Throw', 'Frost Breath'], Charged Moves: ['Weather Ball (Ice)', 'Meteor Beam', 'Ancient Power', 'Thunderbolt', 'Blizzard', 'Hyper Beam'], Recommended Fast: Powder Snow, Recommended Charged: ['Weather Ball (Ice)', 'Meteor Beam']
# Name: Aurorus, Stats: {'Attack': '114.1', 'Defense': '105.7', 'Stamina': '163', 'Overall': '1967'}, Fast Moves: ['Powder Snow', 'Rock Throw', 'Frost Breath'], Charged Moves: ['Weather Ball (Ice)', 'Meteor Beam', 'Ancient Power', 'Thunderbolt', 'Blizzard', 'Hyper Beam'], Recommended Fast: Powder Snow, Recommended Charged: ['Weather Ball (Ice)', 'Meteor Beam']
# Name: Marowak (Alolan) (Shadow), Stats: {'Attack': '110.8', 'Defense': '145', 'Stamina': '126', 'Overall': '2025'}, Fast Moves: ['Hex', 'Fire Spin', 'Rock Smash'], Charged Moves: ['Bone Club', 'Shadow Bone*', 'Fire Blast', 'Shadow Ball', 'Flame Wheel', 'Frustration†'], Recommended Fast: Fire Spin, Recommended Charged: ['Bone Club', 'Shadow Bone*']
# Name: Marowak (Alolan) (Shadow), Stats: {'Attack': '110.8', 'Defense': '145', 'Stamina': '126', 'Overall': '2025'}, Fast Moves: ['Hex', 'Fire Spin', 'Rock Smash'], Charged Moves: ['Bone Club', 'Shadow Bone*', 'Fire Blast', 'Shadow Ball', 'Flame Wheel', 'Frustration†'], Recommended Fast: Fire Spin, Recommended Charged: ['Bone Club', 'Shadow Bone*']
# Name: Togetic, Stats: {'Attack': '110.5', 'Defense': '149.9', 'Stamina': '122', 'Overall': '2023'}, Fast Moves: ['Fairy Wind', 'Steel Wing*', 'Extrasensory', 'Hidden Power (Flying)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Dark)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt*'], Charged Moves: ['Psyshock', 'Aerial Ace', 'Dazzling Gleam', 'Ancient Power', 'Draining Kiss'], Recommended Fast: Fairy Wind, Recommended Charged: ['Psyshock', 'Dazzling Gleam']
# Name: Togetic, Stats: {'Attack': '110.5', 'Defense': '149.9', 'Stamina': '122', 'Overall': '2023'}, Fast Moves: ['Fairy Wind', 'Steel Wing*', 'Extrasensory', 'Hidden Power (Flying)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Dark)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt*'], Charged Moves: ['Psyshock', 'Aerial Ace', 'Dazzling Gleam', 'Ancient Power', 'Draining Kiss'], Recommended Fast: Fairy Wind, Recommended Charged: ['Psyshock', 'Dazzling Gleam']
# Name: Weezing (Galarian), Stats: {'Attack': '118.3', 'Defense': '138.8', 'Stamina': '115', 'Overall': '1890'}, Fast Moves: ['Fairy Wind', 'Tackle'], Charged Moves: ['Sludge', 'Brutal Swing', 'Play Rough', 'Overheat', 'Return†', 'Hyper Beam'], Recommended Fast: Fairy Wind, Recommended Charged: ['Sludge', 'Brutal Swing']
# Name: Weezing (Galarian), Stats: {'Attack': '118.3', 'Defense': '138.8', 'Stamina': '115', 'Overall': '1890'}, Fast Moves: ['Fairy Wind', 'Tackle'], Charged Moves: ['Sludge', 'Brutal Swing', 'Play Rough', 'Overheat', 'Return†', 'Hyper Beam'], Recommended Fast: Fairy Wind, Recommended Charged: ['Sludge', 'Brutal Swing']
# Name: Whiscash (Shadow), Stats: {'Attack': '107.5', 'Defense': '107.5', 'Stamina': '178', 'Overall': '2061'}, Fast Moves: ['Mud Shot', 'Water Gun'], Charged Moves: ['Mud Bomb', 'Scald', 'Blizzard', 'Water Pulse', 'Frustration†'], Recommended Fast: Mud Shot, Recommended Charged: ['Mud Bomb', 'Scald']
# Name: Whiscash (Shadow), Stats: {'Attack': '107.5', 'Defense': '107.5', 'Stamina': '178', 'Overall': '2061'}, Fast Moves: ['Mud Shot', 'Water Gun'], Charged Moves: ['Mud Bomb', 'Scald', 'Blizzard', 'Water Pulse', 'Frustration†'], Recommended Fast: Mud Shot, Recommended Charged: ['Mud Bomb', 'Scald']
# Name: Drapion (Shadow), Stats: {'Attack': '118.5', 'Defense': '136.4', 'Stamina': '117', 'Overall': '1892'}, Fast Moves: ['Poison Sting', 'Ice Fang', 'Infestation', 'Bite'], Charged Moves: ['Aqua Tail', 'Crunch', 'Sludge Bomb', 'Fell Stinger', 'Frustration†'], Recommended Fast: Poison Sting, Recommended Charged: ['Aqua Tail', 'Crunch']
# Name: Drapion (Shadow), Stats: {'Attack': '118.5', 'Defense': '136.4', 'Stamina': '117', 'Overall': '1892'}, Fast Moves: ['Poison Sting', 'Ice Fang', 'Infestation', 'Bite'], Charged Moves: ['Aqua Tail', 'Crunch', 'Sludge Bomb', 'Fell Stinger', 'Frustration†'], Recommended Fast: Poison Sting, Recommended Charged: ['Aqua Tail', 'Crunch']
# Name: Grumpig (Shadow), Stats: {'Attack': '114.5', 'Defense': '128.2', 'Stamina': '133', 'Overall': '1954'}, Fast Moves: ['Psywave', 'Extrasensory', 'Charge Beam'], Charged Moves: ['Dynamic Punch', 'Shadow Ball', 'Psychic', 'Mirror Coat', 'Frustration†'], Recommended Fast: Psywave, Recommended Charged: ['Dynamic Punch', 'Shadow Ball']
# Name: Grumpig (Shadow), Stats: {'Attack': '114.5', 'Defense': '128.2', 'Stamina': '133', 'Overall': '1954'}, Fast Moves: ['Psywave', 'Extrasensory', 'Charge Beam'], Charged Moves: ['Dynamic Punch', 'Shadow Ball', 'Psychic', 'Mirror Coat', 'Frustration†'], Recommended Fast: Psywave, Recommended Charged: ['Dynamic Punch', 'Shadow Ball']
# Name: Regidrago, Stats: {'Attack': '121.8', 'Defense': '62.7', 'Stamina': '241', 'Overall': '1842'}, Fast Moves: ['Dragon Breath*', 'Bite'], Charged Moves: ['Dragon Energy*', 'Breaking Swipe', 'Outrage', 'Hyper Beam', 'Dragon Pulse'], Recommended Fast: Dragon Breath*, Recommended Charged: ['Dragon Energy*', 'Breaking Swipe']
# Name: Regidrago, Stats: {'Attack': '121.8', 'Defense': '62.7', 'Stamina': '241', 'Overall': '1842'}, Fast Moves: ['Dragon Breath*', 'Bite'], Charged Moves: ['Dragon Energy*', 'Breaking Swipe', 'Outrage', 'Hyper Beam', 'Dragon Pulse'], Recommended Fast: Dragon Breath*, Recommended Charged: ['Dragon Energy*', 'Breaking Swipe']
# ...
# Name: Unfezant (Shadow), Stats: {'Attack': '139.1', 'Defense': '96.1', 'Stamina': '120', 'Overall': '1607'}, Fast Moves: ['Air Slash', 'Steel Wing'], Charged Moves: ['Sky Attack', 'Hyper Beam', 'Heat Wave', 'Frustration†'], Recommended Fast: Air Slash, Recommended Charged: ['Sky Attack', 'Hyper Beam']
# Name: Turtwig (Shadow), Stats: {'Attack': '112.6', 'Defense': '105', 'Stamina': '135', 'Overall': '1597'}, Fast Moves: ['Tackle', 'Razor Leaf'], Charged Moves: ['Body Slam', 'Seed Bomb', 'Energy Ball', 'Frustration†'], Recommended Fast: Tackle, Recommended Charged: ['Body Slam', 'Seed Bomb']
# Name: Turtwig (Shadow), Stats: {'Attack': '112.6', 'Defense': '105', 'Stamina': '135', 'Overall': '1597'}, Fast Moves: ['Tackle', 'Razor Leaf'], Charged Moves: ['Body Slam', 'Seed Bomb', 'Energy Ball', 'Frustration†'], Recommended Fast: Tackle, Recommended Charged: ['Body Slam', 'Seed Bomb']
# Name: Noivern, Stats: {'Attack': '126.4', 'Defense': '110.6', 'Stamina': '127', 'Overall': '1777'}, Fast Moves: ['Air Slash', 'Bite'], Charged Moves: ['Hurricane', 'Draco Meteor', 'Boomburst*', 'Psychic', 'Heat Wave'], Recommended Fast: Air Slash, Recommended Charged: ['Hurricane', 'Draco Meteor']
# Name: Noivern, Stats: {'Attack': '126.4', 'Defense': '110.6', 'Stamina': '127', 'Overall': '1777'}, Fast Moves: ['Air Slash', 'Bite'], Charged Moves: ['Hurricane', 'Draco Meteor', 'Boomburst*', 'Psychic', 'Heat Wave'], Recommended Fast: Air Slash, Recommended Charged: ['Hurricane', 'Draco Meteor']
# Name: Chatot, Stats: {'Attack': '140.3', 'Defense': '78.4', 'Stamina': '145', 'Overall': '1596'}, Fast Moves: ['Steel Wing', 'Peck'], Charged Moves: ['Sky Attack', 'Night Shade', 'Heat Wave'], Recommended Fast: Steel Wing, Recommended Charged: ['Sky Attack', 'Night Shade']
# Name: Chatot, Stats: {'Attack': '140.3', 'Defense': '78.4', 'Stamina': '145', 'Overall': '1596'}, Fast Moves: ['Steel Wing', 'Peck'], Charged Moves: ['Sky Attack', 'Night Shade', 'Heat Wave'], Recommended Fast: Steel Wing, Recommended Charged: ['Sky Attack', 'Night Shade']
# Name: Throh (Shadow), Stats: {'Attack': '110.2', 'Defense': '107.7', 'Stamina': '170', 'Overall': '2020'}, Fast Moves: ['Low Kick', 'Zen Headbutt'], Charged Moves: ['Body Slam', 'Brick Break', 'Focus Blast', 'Low Sweep', 'Frustration†'], Recommended Fast: Low Kick, Recommended Charged: ['Body Slam', 'Brick Break']
# Name: Throh (Shadow), Stats: {'Attack': '110.2', 'Defense': '107.7', 'Stamina': '170', 'Overall': '2020'}, Fast Moves: ['Low Kick', 'Zen Headbutt'], Charged Moves: ['Body Slam', 'Brick Break', 'Focus Blast', 'Low Sweep', 'Frustration†'], Recommended Fast: Low Kick, Recommended Charged: ['Body Slam', 'Brick Break']
# Name: Reuniclus, Stats: {'Attack': '127.5', 'Defense': '93.6', 'Stamina': '147', 'Overall': '1756'}, Fast Moves: ['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'], Charged Moves: ['Psyshock', 'Shadow Ball', 'Thunder', 'Future Sight'], Recommended Fast: Hidden Power (Fighting), Recommended Charged: ['Psyshock', 'Shadow Ball']
# Name: Reuniclus, Stats: {'Attack': '127.5', 'Defense': '93.6', 'Stamina': '147', 'Overall': '1756'}, Fast Moves: ['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'], Charged Moves: ['Psyshock', 'Shadow Ball', 'Thunder', 'Future Sight'], Recommended Fast: Hidden Power (Fighting), Recommended Charged: ['Psyshock', 'Shadow Ball']
# Name: Meltan, Stats: {'Attack': '111.7', 'Defense': '95.7', 'Stamina': '121', 'Overall': '1295'}, Fast Moves: ['Thunder Shock'], Charged Moves: ['Thunderbolt', 'Flash Cannon'], Recommended Fast: Thunder Shock, Recommended Charged: ['Thunderbolt', 'Flash Cannon']
# Name: Meltan, Stats: {'Attack': '111.7', 'Defense': '95.7', 'Stamina': '121', 'Overall': '1295'}, Fast Moves: ['Thunder Shock'], Charged Moves: ['Thunderbolt', 'Flash Cannon'], Recommended Fast: Thunder Shock, Recommended Charged: ['Thunderbolt', 'Flash Cannon']
# Name: Axew, Stats: {'Attack': '139.4', 'Defense': '95.2', 'Stamina': '121', 'Overall': '1607'}, Fast Moves: ['Scratch', 'Iron Tail'], Charged Moves: ['Dragon Claw', 'Aqua Tail', 'Dragon Pulse'], Recommended Fast: Scratch, Recommended Charged: ['Dragon Claw', 'Aqua Tail']
# Name: Axew, Stats: {'Attack': '139.4', 'Defense': '95.2', 'Stamina': '121', 'Overall': '1607'}, Fast Moves: ['Scratch', 'Iron Tail'], Charged Moves: ['Dragon Claw', 'Aqua Tail', 'Dragon Pulse'], Recommended Fast: Scratch, Recommended Charged: ['Dragon Claw', 'Aqua Tail']
# Name: Ferroseed, Stats: {'Attack': '81.5', 'Defense': '142.8', 'Stamina': '119', 'Overall': '1386'}, Fast Moves: ['Metal Claw', 'Tackle'], Charged Moves: ['Iron Head', 'Return†', 'Flash Cannon', 'Gyro Ball'], Recommended Fast: Metal Claw, Recommended Charged: ['Iron Head', 'Return†']
# Name: Ferroseed, Stats: {'Attack': '81.5', 'Defense': '142.8', 'Stamina': '119', 'Overall': '1386'}, Fast Moves: ['Metal Claw', 'Tackle'], Charged Moves: ['Iron Head', 'Return†', 'Flash Cannon', 'Gyro Ball'], Recommended Fast: Metal Claw, Recommended Charged: ['Iron Head', 'Return†']
# Name: Swirlix, Stats: {'Attack': '104.1', 'Defense': '112.6', 'Stamina': '145', 'Overall': '1701'}, Fast Moves: ['Tackle'], Charged Moves: ['Energy Ball', 'Draining Kiss'], Recommended Fast: Tackle, Recommended Charged: ['Energy Ball', 'Draining Kiss']
# Name: Swirlix, Stats: {'Attack': '104.1', 'Defense': '112.6', 'Stamina': '145', 'Overall': '1701'}, Fast Moves: ['Tackle'], Charged Moves: ['Energy Ball', 'Draining Kiss'], Recommended Fast: Tackle, Recommended Charged: ['Energy Ball', 'Draining Kiss']
# Name: Ferroseed (Shadow), Stats: {'Attack': '81.5', 'Defense': '142.8', 'Stamina': '119', 'Overall': '1386'}, Fast Moves: ['Metal Claw', 'Tackle'], Charged Moves: ['Iron Head', 'Flash Cannon', 'Gyro Ball', 'Frustration†'], Recommended Fast: Metal Claw, Recommended Charged: ['Iron Head', 'Flash Cannon']
# Name: Ferroseed (Shadow), Stats: {'Attack': '81.5', 'Defense': '142.8', 'Stamina': '119', 'Overall': '1386'}, Fast Moves: ['Metal Claw', 'Tackle'], Charged Moves: ['Iron Head', 'Flash Cannon', 'Gyro Ball', 'Frustration†'], Recommended Fast: Metal Claw, Recommended Charged: ['Iron Head', 'Flash Cannon']
# Name: Unfezant, Stats: {'Attack': '139.1', 'Defense': '96.1', 'Stamina': '120', 'Overall': '1607'}, Fast Moves: ['Air Slash', 'Steel Wing'], Charged Moves: ['Sky Attack', 'Hyper Beam', 'Heat Wave'], Recommended Fast: Air Slash, Recommended Charged: ['Sky Attack', 'Hyper Beam']
# Name: Unfezant, Stats: {'Attack': '139.1', 'Defense': '96.1', 'Stamina': '120', 'Overall': '1607'}, Fast Moves: ['Air Slash', 'Steel Wing'], Charged Moves: ['Sky Attack', 'Hyper Beam', 'Heat Wave'], Recommended Fast: Air Slash, Recommended Charged: ['Sky Attack', 'Hyper Beam']
# Name: Tornadus (Incarnate), Stats: {'Attack': '147.5', 'Defense': '97.1', 'Stamina': '106', 'Overall': '1520'}, Fast Moves: ['Air Slash', 'Bite'], Charged Moves: ['Grass Knot', 'Hurricane', 'Dark Pulse', 'Hyper Beam'], Recommended Fast: Air Slash, Recommended Charged: ['Grass Knot', 'Hurricane']
# Name: Tornadus (Incarnate), Stats: {'Attack': '147.5', 'Defense': '97.1', 'Stamina': '106', 'Overall': '1520'}, Fast Moves: ['Air Slash', 'Bite'], Charged Moves: ['Grass Knot', 'Hurricane', 'Dark Pulse', 'Hyper Beam'], Recommended Fast: Air Slash, Recommended Charged: ['Grass Knot', 'Hurricane']
# Name: Timburr, Stats: {'Attack': '125.2', 'Defense': '85.7', 'Stamina': '164', 'Overall': '1760'}, Fast Moves: ['Low Kick', 'Pound'], Charged Moves: ['Rock Tomb', 'Brick Break', 'Return†', 'Low Sweep'], Recommended Fast: Low Kick, Recommended Charged: ['Rock Tomb', 'Brick Break']
# Name: Timburr, Stats: {'Attack': '125.2', 'Defense': '85.7', 'Stamina': '164', 'Overall': '1760'}, Fast Moves: ['Low Kick', 'Pound'], Charged Moves: ['Rock Tomb', 'Brick Break', 'Return†', 'Low Sweep'], Recommended Fast: Low Kick, Recommended Charged: ['Rock Tomb', 'Brick Break']
# Name: Duosion (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Duosion (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Snubbull, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Snubbull, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Solosis (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Solosis (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Deoxys (Speed), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Deoxys (Speed), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Anorith (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Anorith (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Munna, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Munna, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Duosion, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Duosion, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Solosis, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Solosis, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Timburr (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Timburr (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Snubbull (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Snubbull (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Anorith, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Anorith, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Regigigas (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Regigigas (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Spoink (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Spoink (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Skiddo, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Skiddo, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Spoink, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Spoink, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Clefairy, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Clefairy, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Kadabra, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Kadabra, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Unown, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Unown, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Mienfoo, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Mienfoo, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Slaking, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Slaking, Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# Name: Slaking (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# All Pokémon stats have been saved to raw_data/pokemon_stats_moves.json
# Name: Slaking (Shadow), Stats: {'Attack': '0', 'Defense': '0', 'Stamina': '0', 'Overall': '0'}, Fast Moves: [], Charged Moves: [], Recommended Fast: None, Recommended Charged: []
# All Pokémon stats have been saved to raw_data/pokemon_stats_moves.json

# %% [markdown]
# # Fix Failed Pokemon Data
#
# Code to retry scraping Pokemon with failed data (Overall: "0" or empty moves) with longer wait time.

# %%
def fix_failed_pokemon_data():
    """
    Function to retry scraping Pokemon with failed data
    Failed data criteria:
    - Overall stat is "0"
    - Empty fast_moves or charged_moves arrays
    - No recommended moves
    """
    input_path = 'raw_data/pokemon_stats_moves.json'
    output_path = 'raw_data/pokemon_stats_moves_fixed.json'
    base_url = 'https://pvpoke.com/rankings/all/1500/overall/'
    
    # Read existing data
    with open(input_path, 'r') as f:
        pokemon_data = json.load(f)
    
    # Find failed Pokemon
    failed_pokemon = []
    for pokemon in pokemon_data:
        # Check if Pokemon has failed data
        overall_stat = pokemon.get('filtered_stats', {}).get('Overall', '0')
        fast_moves = pokemon.get('fast_moves', [])
        charged_moves = pokemon.get('charged_moves', [])
        
        if (overall_stat == "0" or 
            len(fast_moves) == 0 or 
            len(charged_moves) == 0):
            failed_pokemon.append(pokemon)
    
    print(f"Found {len(failed_pokemon)} Pokemon with failed data")
    
    if len(failed_pokemon) == 0:
        print("No failed Pokemon found!")
        return
    
    # Print names of failed Pokemon
    print("Failed Pokemon:")
    for pokemon in failed_pokemon:
        print(f"- {pokemon['name']}")
    
    driver = webdriver.Chrome()
    
    try:
        # Navigate to main page first
        url = 'https://pvpoke.com/rankings/'
        driver.get(url)
        time.sleep(10)
        
        fixed_data = []
        
        for i, pokemon in enumerate(failed_pokemon):
            name = pokemon['name']
            print(f"\nRetrying {i+1}/{len(failed_pokemon)}: {name}")
            
            # Format name for URL
            formatted_name = name.replace('(', '').replace(')', '').replace(' ', '_').replace('-','_').replace("'", '').replace('.','_')
            url = f"{base_url}{formatted_name.lower()}/"
            
            driver.get(url)
            time.sleep(15)  # Longer wait time
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            
            # Get detailed stats
            stat_details = soup.find('div', class_='stat-details clear')
            filtered_stats = {}
            if stat_details:
                for stat_row in stat_details.find_all('div', class_='stat-row'):
                    label = stat_row.find('div', class_='label')
                    value = stat_row.find('div', class_='value')
                    if label and value:
                        label_text = label.text.strip()
                        value_text = value.text.strip()
                        if label_text in ['Attack', 'Defense', 'Overall', 'Stamina']:
                            filtered_stats[label_text] = value_text
            
            # Get fast moves
            fast_moves_section = soup.find('div', class_='moveset fast show-stats clear')
            fast_moves = []
            recommended_fast_move = None
            
            if fast_moves_section:
                move_elements = fast_moves_section.find_all('div', class_='move-detail-template')
                for move in move_elements:
                    move_classes = move.get('class', [])
                    if 'hide' not in move_classes:
                        name_span = move.find('span', class_='name')
                        if name_span:
                            move_name = name_span.text.strip()
                            fast_moves.append(move_name)
                            if 'selected' in move_classes:
                                recommended_fast_move = move_name
            
            # Get charged moves
            charged_moves_section = soup.find('div', class_='moveset charged show-stats clear')
            charged_moves = []
            recommended_charged_moves = []
            
            if charged_moves_section:
                move_elements = charged_moves_section.find_all('div', class_='move-detail-template')
                for move in move_elements:
                    move_classes = move.get('class', [])
                    if 'hide' not in move_classes:
                        name_span = move.find('span', class_='name')
                        if name_span:
                            move_name = name_span.text.strip()
                            charged_moves.append(move_name)
                            if 'selected' in move_classes:
                                recommended_charged_moves.append(move_name)
            
            # Create fixed Pokemon data
            fixed_pokemon = {
                'name': name,
                'filtered_stats': filtered_stats,
                'fast_moves': fast_moves,
                'charged_moves': charged_moves,
                'recommended_fast_move': recommended_fast_move,
                'recommended_charged_moves': recommended_charged_moves
            }
            
            fixed_data.append(fixed_pokemon)
            
            # Print results
            overall = filtered_stats.get('Overall', '0')
            print(f"  Overall: {overall}")
            print(f"  Fast moves: {len(fast_moves)} ({fast_moves})")
            print(f"  Charged moves: {len(charged_moves)} ({charged_moves})")
            print(f"  Recommended fast: {recommended_fast_move}")
            print(f"  Recommended charged: {recommended_charged_moves}")
            
            # Check if still failed
            if overall == "0" or len(fast_moves) == 0 or len(charged_moves) == 0:
                print(f"  ⚠️  Still failed after retry!")
            else:
                print(f"  ✅ Successfully fixed!")
        
        # Save fixed data
        with open(output_path, 'w') as f:
            json.dump(fixed_data, f, indent=4)
        
        print(f"\n🎉 Fixed data saved to {output_path}")
        print(f"Total Pokemon processed: {len(fixed_data)}")
        
    finally:
        driver.quit()

# Uncomment to run:
# fix_failed_pokemon_data()

# %%
def update_original_data_with_fixes():
    """
    Function to update the original pokemon_stats_moves.json file 
    with the fixed data from pokemon_stats_moves_fixed.json
    """
    original_path = 'raw_data/pokemon_stats_moves.json'
    fixed_path = 'raw_data/pokemon_stats_moves_fixed.json'
    backup_path = 'raw_data/pokemon_stats_moves_backup.json'
    
    # Check if fixed data exists
    try:
        with open(fixed_path, 'r') as f:
            fixed_data = json.load(f)
    except FileNotFoundError:
        print(f"❌ Fixed data file not found: {fixed_path}")
        print("Please run fix_failed_pokemon_data() first!")
        return
    
    # Read original data
    with open(original_path, 'r') as f:
        original_data = json.load(f)
    
    # Create backup
    with open(backup_path, 'w') as f:
        json.dump(original_data, f, indent=4)
    print(f"💾 Backup created: {backup_path}")
    
    # Create a dictionary for quick lookup of fixed data
    fixed_dict = {pokemon['name']: pokemon for pokemon in fixed_data}
    
    # Update original data
    updated_count = 0
    for i, pokemon in enumerate(original_data):
        name = pokemon['name']
        if name in fixed_dict:
            # Replace with fixed data
            original_data[i] = fixed_dict[name]
            updated_count += 1
            print(f"✅ Updated: {name}")
    
    # Save updated data
    with open(original_path, 'w') as f:
        json.dump(original_data, f, indent=4)
    
    print(f"\n🎉 Successfully updated {updated_count} Pokemon in {original_path}")
    print(f"📁 Original data backed up to: {backup_path}")

# Uncomment to run:
# update_original_data_with_fixes()

# %%
# Run the fix function
fix_failed_pokemon_data()
# Out:
# Found 54 Pokemon with failed data
# Failed Pokemon:
# - Zygarde (50% Forme)
# - Mr. Mime
# - Cherrim (Sunshine)
# - Wyrdeer
# - Nuzleaf
# - Teddiursa
# - Onix
# - Zygarde (10% Forme)
# - Ambipom
# - Lycanroc (Dusk)
# - Darmanitan (Galarian)
# - Meowstic (Male)
# - Mr. Rime
# - Mr. Mime (Galarian)
# - Rampardos
# - Xatu
# - Bergmite
# - Bulbasaur (Shadow)
# - Clawitzer
# - Deerling
# - Shaymin (Sky)
# - Pupitar
# - Inteleon
# - Snover (Shadow)
# - Drowzee
# - Elgyem
# - Gorebyss
# - Accelgor
# - Porygon-Z (Shadow)
# - Flabebe
# - Rowlet
# - Reuniclus (Shadow)
# - Throh
# - Duosion (Shadow)
# - Snubbull
# - Solosis (Shadow)
# - Deoxys (Speed)
# - Anorith (Shadow)
# - Munna
# - Duosion
# - Solosis
# - Timburr (Shadow)
# - Snubbull (Shadow)
# - Anorith
# - Regigigas (Shadow)
# - Spoink (Shadow)
# - Skiddo
# - Spoink
# - Clefairy
# - Kadabra
# - Unown
# - Mienfoo
# - Slaking
# - Slaking (Shadow)
#
# Retrying 1/54: Zygarde (50% Forme)
#
# Retrying 1/54: Zygarde (50% Forme)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 2/54: Mr. Mime
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 2/54: Mr. Mime
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 3/54: Cherrim (Sunshine)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 3/54: Cherrim (Sunshine)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 4/54: Wyrdeer
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 4/54: Wyrdeer
#   Overall: 1758
#   Fast moves: 3 (['Confusion', 'Tackle', 'Zen Headbutt'])
#   Charged moves: 4 (['Wild Charge', 'Stomp', 'Megahorn', 'Psychic'])
#   Recommended fast: Confusion
#   Recommended charged: ['Wild Charge', 'Stomp']
#   ✅ Successfully fixed!
#
# Retrying 5/54: Nuzleaf
#   Overall: 1758
#   Fast moves: 3 (['Confusion', 'Tackle', 'Zen Headbutt'])
#   Charged moves: 4 (['Wild Charge', 'Stomp', 'Megahorn', 'Psychic'])
#   Recommended fast: Confusion
#   Recommended charged: ['Wild Charge', 'Stomp']
#   ✅ Successfully fixed!
#
# Retrying 5/54: Nuzleaf
#   Overall: 1536
#   Fast moves: 2 (['Feint Attack', 'Razor Leaf'])
#   Charged moves: 4 (['Leaf Blade', 'Foul Play', 'Grass Knot', 'Return†'])
#   Recommended fast: Feint Attack
#   Recommended charged: ['Leaf Blade', 'Foul Play']
#   ✅ Successfully fixed!
#
# Retrying 6/54: Teddiursa
#   Overall: 1536
#   Fast moves: 2 (['Feint Attack', 'Razor Leaf'])
#   Charged moves: 4 (['Leaf Blade', 'Foul Play', 'Grass Knot', 'Return†'])
#   Recommended fast: Feint Attack
#   Recommended charged: ['Leaf Blade', 'Foul Play']
#   ✅ Successfully fixed!
#
# Retrying 6/54: Teddiursa
#   Overall: 1678
#   Fast moves: 2 (['Lick', 'Scratch'])
#   Charged moves: 6 (['Swift', 'Cross Chop', 'Trailblaze', 'Crunch', 'Play Rough', 'Return†'])
#   Recommended fast: Lick
#   Recommended charged: ['Swift', 'Cross Chop']
#   ✅ Successfully fixed!
#
# Retrying 7/54: Onix
#   Overall: 1678
#   Fast moves: 2 (['Lick', 'Scratch'])
#   Charged moves: 6 (['Swift', 'Cross Chop', 'Trailblaze', 'Crunch', 'Play Rough', 'Return†'])
#   Recommended fast: Lick
#   Recommended charged: ['Swift', 'Cross Chop']
#   ✅ Successfully fixed!
#
# Retrying 7/54: Onix
#   Overall: 1831
#   Fast moves: 2 (['Rock Throw', 'Tackle'])
#   Charged moves: 7 (['Breaking Swipe', 'Stone Edge', 'Rock Slide*', 'Sand Tomb', 'Heavy Slam', 'Return†', 'Iron Head*'])
#   Recommended fast: Rock Throw
#   Recommended charged: ['Breaking Swipe', 'Stone Edge']
#   ✅ Successfully fixed!
#
# Retrying 8/54: Zygarde (10% Forme)
#   Overall: 1831
#   Fast moves: 2 (['Rock Throw', 'Tackle'])
#   Charged moves: 7 (['Breaking Swipe', 'Stone Edge', 'Rock Slide*', 'Sand Tomb', 'Heavy Slam', 'Return†', 'Iron Head*'])
#   Recommended fast: Rock Throw
#   Recommended charged: ['Breaking Swipe', 'Stone Edge']
#   ✅ Successfully fixed!
#
# Retrying 8/54: Zygarde (10% Forme)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 9/54: Ambipom
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 9/54: Ambipom
#   Overall: 1659
#   Fast moves: 2 (['Astonish', 'Scratch'])
#   Charged moves: 4 (['Aerial Ace', 'Return†', 'Low Sweep', 'Hyper Beam'])
#   Recommended fast: Astonish
#   Recommended charged: ['Aerial Ace', 'Return†']
#   ✅ Successfully fixed!
#
# Retrying 10/54: Lycanroc (Dusk)
#   Overall: 1659
#   Fast moves: 2 (['Astonish', 'Scratch'])
#   Charged moves: 4 (['Aerial Ace', 'Return†', 'Low Sweep', 'Hyper Beam'])
#   Recommended fast: Astonish
#   Recommended charged: ['Aerial Ace', 'Return†']
#   ✅ Successfully fixed!
#
# Retrying 10/54: Lycanroc (Dusk)
#   Overall: 1545
#   Fast moves: 3 (['Sucker Punch', 'Counter', 'Rock Throw'])
#   Charged moves: 4 (['Stone Edge', 'Trailblaze', 'Crunch', 'Iron Head'])
#   Recommended fast: Sucker Punch
#   Recommended charged: ['Stone Edge', 'Trailblaze']
#   ✅ Successfully fixed!
#
# Retrying 11/54: Darmanitan (Galarian)
#   Overall: 1545
#   Fast moves: 3 (['Sucker Punch', 'Counter', 'Rock Throw'])
#   Charged moves: 4 (['Stone Edge', 'Trailblaze', 'Crunch', 'Iron Head'])
#   Recommended fast: Sucker Punch
#   Recommended charged: ['Stone Edge', 'Trailblaze']
#   ✅ Successfully fixed!
#
# Retrying 11/54: Darmanitan (Galarian)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 12/54: Meowstic (Male)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 12/54: Meowstic (Male)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 13/54: Mr. Rime
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 13/54: Mr. Rime
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 14/54: Mr. Mime (Galarian)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 14/54: Mr. Mime (Galarian)
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 15/54: Rampardos
#   Overall: 0
#   Fast moves: 0 ([])
#   Charged moves: 0 ([])
#   Recommended fast: None
#   Recommended charged: []
#   ⚠️  Still failed after retry!
#
# Retrying 15/54: Rampardos
#   Overall: 1363
#   Fast moves: 2 (['Smack Down', 'Zen Headbutt'])
#   Charged moves: 3 (['Rock Slide', 'Flamethrower', 'Outrage'])
#   Recommended fast: Smack Down
#   Recommended charged: ['Rock Slide', 'Flamethrower']
#   ✅ Successfully fixed!
#
# Retrying 16/54: Xatu
#   Overall: 1363
#   Fast moves: 2 (['Smack Down', 'Zen Headbutt'])
#   Charged moves: 3 (['Rock Slide', 'Flamethrower', 'Outrage'])
#   Recommended fast: Smack Down
#   Recommended charged: ['Rock Slide', 'Flamethrower']
#   ✅ Successfully fixed!
#
# Retrying 16/54: Xatu
#   Overall: 1682
#   Fast moves: 2 (['Air Slash', 'Feint Attack'])
#   Charged moves: 4 (['Aerial Ace', 'Future Sight', 'Ominous Wind', 'Return†'])
#   Recommended fast: Air Slash
#   Recommended charged: ['Aerial Ace', 'Future Sight']
#   ✅ Successfully fixed!
#
# Retrying 17/54: Bergmite
#   Overall: 1682
#   Fast moves: 2 (['Air Slash', 'Feint Attack'])
#   Charged moves: 4 (['Aerial Ace', 'Future Sight', 'Ominous Wind', 'Return†'])
#   Recommended fast: Air Slash
#   Recommended charged: ['Aerial Ace', 'Future Sight']
#   ✅ Successfully fixed!
#
# Retrying 17/54: Bergmite
#   Overall: 1699
#   Fast moves: 2 (['Tackle', 'Bite'])
#   Charged moves: 3 (['Icy Wind', 'Crunch', 'Mirror Coat'])
#   Recommended fast: Tackle
#   Recommended charged: ['Icy Wind', 'Crunch']
#   ✅ Successfully fixed!
#
# Retrying 18/54: Bulbasaur (Shadow)
#   Overall: 1699
#   Fast moves: 2 (['Tackle', 'Bite'])
#   Charged moves: 3 (['Icy Wind', 'Crunch', 'Mirror Coat'])
#   Recommended fast: Tackle
#   Recommended charged: ['Icy Wind', 'Crunch']
#   ✅ Successfully fixed!
#
# Retrying 18/54: Bulbasaur (Shadow)
#   Overall: 1420
#   Fast moves: 2 (['Vine Whip', 'Tackle'])
#   Charged moves: 4 (['Power Whip', 'Sludge Bomb', 'Seed Bomb', 'Frustration†'])
#   Recommended fast: Vine Whip
#   Recommended charged: ['Power Whip', 'Sludge Bomb']
#   ✅ Successfully fixed!
#
# Retrying 19/54: Clawitzer
#   Overall: 1420
#   Fast moves: 2 (['Vine Whip', 'Tackle'])
#   Charged moves: 4 (['Power Whip', 'Sludge Bomb', 'Seed Bomb', 'Frustration†'])
#   Recommended fast: Vine Whip
#   Recommended charged: ['Power Whip', 'Sludge Bomb']
#   ✅ Successfully fixed!
#
# Retrying 19/54: Clawitzer
#   Overall: 1649
#   Fast moves: 2 (['Water Gun', 'Smack Down'])
#   Charged moves: 4 (['Crabhammer', 'Dark Pulse', 'Ice Beam', 'Water Pulse'])
#   Recommended fast: Water Gun
#   Recommended charged: ['Crabhammer', 'Ice Beam']
#   ✅ Successfully fixed!
#
# Retrying 20/54: Deerling
#   Overall: 1649
#   Fast moves: 2 (['Water Gun', 'Smack Down'])
#   Charged moves: 4 (['Crabhammer', 'Dark Pulse', 'Ice Beam', 'Water Pulse'])
#   Recommended fast: Water Gun
#   Recommended charged: ['Crabhammer', 'Ice Beam']
#   ✅ Successfully fixed!
#
# Retrying 20/54: Deerling
#   Overall: 1499
#   Fast moves: 2 (['Tackle', 'Take Down'])
#   Charged moves: 4 (['Wild Charge', 'Trailblaze', 'Seed Bomb', 'Energy Ball'])
#   Recommended fast: Tackle
#   Recommended charged: ['Wild Charge', 'Trailblaze']
#   ✅ Successfully fixed!
#
# Retrying 21/54: Shaymin (Sky)
#   Overall: 1499
#   Fast moves: 2 (['Tackle', 'Take Down'])
#   Charged moves: 4 (['Wild Charge', 'Trailblaze', 'Seed Bomb', 'Energy Ball'])
#   Recommended fast: Tackle
#   Recommended charged: ['Wild Charge', 'Trailblaze']
#   ✅ Successfully fixed!
#
# Retrying 21/54: Shaymin (Sky)
#   Overall: 1604
#   Fast moves: 18 (['Magical Leaf', 'Hidden Power (Flying)', 'Hidden Power (Grass)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Dark)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Steel)', 'Hidden Power (Dragon)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Grass Knot', 'Energy Ball', 'Seed Flare*', 'Solar Beam'])
#   Recommended fast: Magical Leaf
#   Recommended charged: ['Grass Knot', 'Energy Ball']
#   ✅ Successfully fixed!
#
# Retrying 22/54: Pupitar
#   Overall: 1604
#   Fast moves: 18 (['Magical Leaf', 'Hidden Power (Flying)', 'Hidden Power (Grass)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Dark)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Steel)', 'Hidden Power (Dragon)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Grass Knot', 'Energy Ball', 'Seed Flare*', 'Solar Beam'])
#   Recommended fast: Magical Leaf
#   Recommended charged: ['Grass Knot', 'Energy Ball']
#   ✅ Successfully fixed!
#
# Retrying 22/54: Pupitar
#   Overall: 1856
#   Fast moves: 2 (['Bite', 'Rock Smash'])
#   Charged moves: 4 (['Ancient Power', 'Dig', 'Crunch', 'Return†'])
#   Recommended fast: Bite
#   Recommended charged: ['Ancient Power', 'Dig']
#   ✅ Successfully fixed!
#
# Retrying 23/54: Inteleon
#   Overall: 1856
#   Fast moves: 2 (['Bite', 'Rock Smash'])
#   Charged moves: 4 (['Ancient Power', 'Dig', 'Crunch', 'Return†'])
#   Recommended fast: Bite
#   Recommended charged: ['Ancient Power', 'Dig']
#   ✅ Successfully fixed!
#
# Retrying 23/54: Inteleon
#   Overall: 1449
#   Fast moves: 2 (['Water Gun', 'Pound'])
#   Charged moves: 3 (['Surf', 'Shadow Ball', 'Water Pulse'])
#   Recommended fast: Water Gun
#   Recommended charged: ['Surf', 'Shadow Ball']
#   ✅ Successfully fixed!
#
# Retrying 24/54: Snover (Shadow)
#   Overall: 1449
#   Fast moves: 2 (['Water Gun', 'Pound'])
#   Charged moves: 3 (['Surf', 'Shadow Ball', 'Water Pulse'])
#   Recommended fast: Water Gun
#   Recommended charged: ['Surf', 'Shadow Ball']
#   ✅ Successfully fixed!
#
# Retrying 24/54: Snover (Shadow)
#   Overall: 1564
#   Fast moves: 3 (['Powder Snow', 'Leafage', 'Ice Shard'])
#   Charged moves: 4 (['Ice Beam', 'Energy Ball', 'Stomp', 'Frustration†'])
#   Recommended fast: Powder Snow
#   Recommended charged: ['Ice Beam', 'Energy Ball']
#   ✅ Successfully fixed!
#
# Retrying 25/54: Drowzee
#   Overall: 1564
#   Fast moves: 3 (['Powder Snow', 'Leafage', 'Ice Shard'])
#   Charged moves: 4 (['Ice Beam', 'Energy Ball', 'Stomp', 'Frustration†'])
#   Recommended fast: Powder Snow
#   Recommended charged: ['Ice Beam', 'Energy Ball']
#   ✅ Successfully fixed!
#
# Retrying 25/54: Drowzee
#   Overall: 1575
#   Fast moves: 2 (['Confusion', 'Pound'])
#   Charged moves: 4 (['Psyshock', 'Return†', 'Psychic', 'Psybeam'])
#   Recommended fast: Confusion
#   Recommended charged: ['Psyshock', 'Return†']
#   ✅ Successfully fixed!
#
# Retrying 26/54: Elgyem
#   Overall: 1575
#   Fast moves: 2 (['Confusion', 'Pound'])
#   Charged moves: 4 (['Psyshock', 'Return†', 'Psychic', 'Psybeam'])
#   Recommended fast: Confusion
#   Recommended charged: ['Psyshock', 'Return†']
#   ✅ Successfully fixed!
#
# Retrying 26/54: Elgyem
#   Overall: 1675
#   Fast moves: 2 (['Confusion', 'Astonish'])
#   Charged moves: 3 (['Dark Pulse', 'Psychic', 'Psybeam'])
#   Recommended fast: Confusion
#   Recommended charged: ['Dark Pulse', 'Psychic']
#   ✅ Successfully fixed!
#
# Retrying 27/54: Gorebyss
#   Overall: 1675
#   Fast moves: 2 (['Confusion', 'Astonish'])
#   Charged moves: 3 (['Dark Pulse', 'Psychic', 'Psybeam'])
#   Recommended fast: Confusion
#   Recommended charged: ['Dark Pulse', 'Psychic']
#   ✅ Successfully fixed!
#
# Retrying 27/54: Gorebyss
#   Overall: 1638
#   Fast moves: 2 (['Water Gun', 'Confusion'])
#   Charged moves: 3 (['Water Pulse', 'Psychic', 'Draining Kiss'])
#   Recommended fast: Water Gun
#   Recommended charged: ['Water Pulse', 'Psychic']
#   ✅ Successfully fixed!
#
# Retrying 28/54: Accelgor
#   Overall: 1638
#   Fast moves: 2 (['Water Gun', 'Confusion'])
#   Charged moves: 3 (['Water Pulse', 'Psychic', 'Draining Kiss'])
#   Recommended fast: Water Gun
#   Recommended charged: ['Water Pulse', 'Psychic']
#   ✅ Successfully fixed!
#
# Retrying 28/54: Accelgor
#   Overall: 1557
#   Fast moves: 3 (['Water Shuriken', 'Acid', 'Infestation'])
#   Charged moves: 6 (['Bug Buzz', 'Energy Ball*', 'Signal Beam', 'Focus Blast', 'Return†', 'Acid Spray'])
#   Recommended fast: Water Shuriken
#   Recommended charged: ['Bug Buzz', 'Acid Spray']
#   ✅ Successfully fixed!
#
# Retrying 29/54: Porygon-Z (Shadow)
#   Overall: 1557
#   Fast moves: 3 (['Water Shuriken', 'Acid', 'Infestation'])
#   Charged moves: 6 (['Bug Buzz', 'Energy Ball*', 'Signal Beam', 'Focus Blast', 'Return†', 'Acid Spray'])
#   Recommended fast: Water Shuriken
#   Recommended charged: ['Bug Buzz', 'Acid Spray']
#   ✅ Successfully fixed!
#
# Retrying 29/54: Porygon-Z (Shadow)
#   Overall: 1512
#   Fast moves: 18 (['Lock On', 'Charge Beam', 'Hidden Power (Ground)', 'Hidden Power (Ice)', 'Hidden Power (Rock)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Flying)', 'Hidden Power (Grass)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Dark)', 'Hidden Power (Steel)', 'Hidden Power (Dragon)', 'Hidden Power (Bug)', 'Hidden Power (Poison)'])
#   Charged moves: 6 (['Tri Attack*', 'Blizzard', 'Zap Cannon', 'Hyper Beam', 'Solar Beam', 'Frustration†'])
#   Recommended fast: Lock On
#   Recommended charged: ['Tri Attack*', 'Zap Cannon']
#   ✅ Successfully fixed!
#
# Retrying 30/54: Flabebe
#   Overall: 1512
#   Fast moves: 18 (['Lock On', 'Charge Beam', 'Hidden Power (Ground)', 'Hidden Power (Ice)', 'Hidden Power (Rock)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Flying)', 'Hidden Power (Grass)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Ghost)', 'Hidden Power (Psychic)', 'Hidden Power (Dark)', 'Hidden Power (Steel)', 'Hidden Power (Dragon)', 'Hidden Power (Bug)', 'Hidden Power (Poison)'])
#   Charged moves: 6 (['Tri Attack*', 'Blizzard', 'Zap Cannon', 'Hyper Beam', 'Solar Beam', 'Frustration†'])
#   Recommended fast: Lock On
#   Recommended charged: ['Tri Attack*', 'Zap Cannon']
#   ✅ Successfully fixed!
#
# Retrying 30/54: Flabebe
#   Overall: 1395
#   Fast moves: 2 (['Vine Whip', 'Tackle'])
#   Charged moves: 3 (['Dazzling Gleam', 'Psychic', 'Petal Blizzard'])
#   Recommended fast: Vine Whip
#   Recommended charged: ['Dazzling Gleam', 'Psychic']
#   ✅ Successfully fixed!
#
# Retrying 31/54: Rowlet
#   Overall: 1395
#   Fast moves: 2 (['Vine Whip', 'Tackle'])
#   Charged moves: 3 (['Dazzling Gleam', 'Psychic', 'Petal Blizzard'])
#   Recommended fast: Vine Whip
#   Recommended charged: ['Dazzling Gleam', 'Psychic']
#   ✅ Successfully fixed!
#
# Retrying 31/54: Rowlet
#   Overall: 1450
#   Fast moves: 4 (['Leafage', 'Magical Leaf', 'Tackle', 'Razor Leaf'])
#   Charged moves: 2 (['Seed Bomb', 'Energy Ball'])
#   Recommended fast: Leafage
#   Recommended charged: ['Seed Bomb', 'Energy Ball']
#   ✅ Successfully fixed!
#
# Retrying 32/54: Reuniclus (Shadow)
#   Overall: 1450
#   Fast moves: 4 (['Leafage', 'Magical Leaf', 'Tackle', 'Razor Leaf'])
#   Charged moves: 2 (['Seed Bomb', 'Energy Ball'])
#   Recommended fast: Leafage
#   Recommended charged: ['Seed Bomb', 'Energy Ball']
#   ✅ Successfully fixed!
#
# Retrying 32/54: Reuniclus (Shadow)
#   Overall: 1756
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Fighting)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 5 (['Psyshock', 'Shadow Ball', 'Thunder', 'Future Sight', 'Frustration†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Shadow Ball']
#   ✅ Successfully fixed!
#
# Retrying 33/54: Throh
#   Overall: 1756
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Fighting)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 5 (['Psyshock', 'Shadow Ball', 'Thunder', 'Future Sight', 'Frustration†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Shadow Ball']
#   ✅ Successfully fixed!
#
# Retrying 33/54: Throh
#   Overall: 2020
#   Fast moves: 2 (['Low Kick', 'Zen Headbutt'])
#   Charged moves: 4 (['Body Slam', 'Brick Break', 'Focus Blast', 'Low Sweep'])
#   Recommended fast: Low Kick
#   Recommended charged: ['Body Slam', 'Brick Break']
#   ✅ Successfully fixed!
#
# Retrying 34/54: Duosion (Shadow)
#   Overall: 2020
#   Fast moves: 2 (['Low Kick', 'Zen Headbutt'])
#   Charged moves: 4 (['Body Slam', 'Brick Break', 'Focus Blast', 'Low Sweep'])
#   Recommended fast: Low Kick
#   Recommended charged: ['Body Slam', 'Brick Break']
#   ✅ Successfully fixed!
#
# Retrying 34/54: Duosion (Shadow)
#   Overall: 1493
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Dark)', 'Hidden Power (Ghost)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Frustration†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 35/54: Snubbull
#   Overall: 1493
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Dark)', 'Hidden Power (Ghost)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Frustration†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 35/54: Snubbull
#   Overall: 1524
#   Fast moves: 2 (['Tackle', 'Bite'])
#   Charged moves: 4 (['Crunch', 'Dazzling Gleam', 'Brick Break', 'Return†'])
#   Recommended fast: Tackle
#   Recommended charged: ['Crunch', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 36/54: Solosis (Shadow)
#   Overall: 1524
#   Fast moves: 2 (['Tackle', 'Bite'])
#   Charged moves: 4 (['Crunch', 'Dazzling Gleam', 'Brick Break', 'Return†'])
#   Recommended fast: Tackle
#   Recommended charged: ['Crunch', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 36/54: Solosis (Shadow)
#   Overall: 1465
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Electric)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Frustration†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 37/54: Deoxys (Speed)
#   Overall: 1465
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Electric)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Frustration†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 37/54: Deoxys (Speed)
#   Overall: 1593
#   Fast moves: 2 (['Charge Beam', 'Zen Headbutt'])
#   Charged moves: 3 (['Psycho Boost', 'Swift', 'Thunderbolt'])
#   Recommended fast: Charge Beam
#   Recommended charged: ['Psycho Boost', 'Swift']
#   ✅ Successfully fixed!
#
# Retrying 38/54: Anorith (Shadow)
#   Overall: 1593
#   Fast moves: 2 (['Charge Beam', 'Zen Headbutt'])
#   Charged moves: 3 (['Psycho Boost', 'Swift', 'Thunderbolt'])
#   Recommended fast: Charge Beam
#   Recommended charged: ['Psycho Boost', 'Swift']
#   ✅ Successfully fixed!
#
# Retrying 38/54: Anorith (Shadow)
#   Overall: 1530
#   Fast moves: 2 (['Struggle Bug', 'Scratch'])
#   Charged moves: 4 (['Aqua Jet', 'Ancient Power', 'Cross Poison', 'Frustration†'])
#   Recommended fast: Struggle Bug
#   Recommended charged: ['Aqua Jet', 'Cross Poison']
#   ✅ Successfully fixed!
#
# Retrying 39/54: Munna
#   Overall: 1530
#   Fast moves: 2 (['Struggle Bug', 'Scratch'])
#   Charged moves: 4 (['Aqua Jet', 'Ancient Power', 'Cross Poison', 'Frustration†'])
#   Recommended fast: Struggle Bug
#   Recommended charged: ['Aqua Jet', 'Cross Poison']
#   ✅ Successfully fixed!
#
# Retrying 39/54: Munna
#   Overall: 1580
#   Fast moves: 2 (['Charge Beam', 'Zen Headbutt'])
#   Charged moves: 3 (['Psyshock', 'Dazzling Gleam', 'Psybeam'])
#   Recommended fast: Charge Beam
#   Recommended charged: ['Psyshock', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 40/54: Duosion
#   Overall: 1580
#   Fast moves: 2 (['Charge Beam', 'Zen Headbutt'])
#   Charged moves: 3 (['Psyshock', 'Dazzling Gleam', 'Psybeam'])
#   Recommended fast: Charge Beam
#   Recommended charged: ['Psyshock', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 40/54: Duosion
#   Overall: 1493
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Ice)', 'Hidden Power (Rock)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Dark)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Return†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 41/54: Solosis
#   Overall: 1493
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Ice)', 'Hidden Power (Rock)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Dark)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Return†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 41/54: Solosis
#   Overall: 1465
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Grass)', 'Hidden Power (Fighting)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Return†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 42/54: Timburr (Shadow)
#   Overall: 1465
#   Fast moves: 17 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Flying)', 'Hidden Power (Fire)', 'Hidden Power (Electric)', 'Hidden Power (Water)', 'Hidden Power (Grass)', 'Hidden Power (Fighting)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 4 (['Psyshock', 'Night Shade', 'Thunder', 'Return†'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Psyshock', 'Night Shade']
#   ✅ Successfully fixed!
#
# Retrying 42/54: Timburr (Shadow)
#   Overall: 1760
#   Fast moves: 2 (['Low Kick', 'Pound'])
#   Charged moves: 4 (['Rock Tomb', 'Brick Break', 'Low Sweep', 'Frustration†'])
#   Recommended fast: Low Kick
#   Recommended charged: ['Rock Tomb', 'Brick Break']
#   ✅ Successfully fixed!
#
# Retrying 43/54: Snubbull (Shadow)
#   Overall: 1760
#   Fast moves: 2 (['Low Kick', 'Pound'])
#   Charged moves: 4 (['Rock Tomb', 'Brick Break', 'Low Sweep', 'Frustration†'])
#   Recommended fast: Low Kick
#   Recommended charged: ['Rock Tomb', 'Brick Break']
#   ✅ Successfully fixed!
#
# Retrying 43/54: Snubbull (Shadow)
#   Overall: 1524
#   Fast moves: 2 (['Tackle', 'Bite'])
#   Charged moves: 4 (['Crunch', 'Dazzling Gleam', 'Brick Break', 'Frustration†'])
#   Recommended fast: Tackle
#   Recommended charged: ['Crunch', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 44/54: Anorith
#   Overall: 1524
#   Fast moves: 2 (['Tackle', 'Bite'])
#   Charged moves: 4 (['Crunch', 'Dazzling Gleam', 'Brick Break', 'Frustration†'])
#   Recommended fast: Tackle
#   Recommended charged: ['Crunch', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 44/54: Anorith
#   Overall: 1530
#   Fast moves: 2 (['Struggle Bug', 'Scratch'])
#   Charged moves: 4 (['Aqua Jet', 'Ancient Power', 'Cross Poison', 'Return†'])
#   Recommended fast: Struggle Bug
#   Recommended charged: ['Aqua Jet', 'Ancient Power']
#   ✅ Successfully fixed!
#
# Retrying 45/54: Regigigas (Shadow)
#   Overall: 1530
#   Fast moves: 2 (['Struggle Bug', 'Scratch'])
#   Charged moves: 4 (['Aqua Jet', 'Ancient Power', 'Cross Poison', 'Return†'])
#   Recommended fast: Struggle Bug
#   Recommended charged: ['Aqua Jet', 'Ancient Power']
#   ✅ Successfully fixed!
#
# Retrying 45/54: Regigigas (Shadow)
#   Overall: 1607
#   Fast moves: 17 (['Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fighting)', 'Hidden Power (Fire)', 'Hidden Power (Flying)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Psychic)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 5 (['Crush Grip*', 'Thunder', 'Focus Blast', 'Giga Impact', 'Frustration†'])
#   Recommended fast: Hidden Power (Ice)
#   Recommended charged: ['Crush Grip*', 'Thunder']
#   ✅ Successfully fixed!
#
# Retrying 46/54: Spoink (Shadow)
#   Overall: 1607
#   Fast moves: 17 (['Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fighting)', 'Hidden Power (Fire)', 'Hidden Power (Flying)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Psychic)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)', 'Zen Headbutt'])
#   Charged moves: 5 (['Crush Grip*', 'Thunder', 'Focus Blast', 'Giga Impact', 'Frustration†'])
#   Recommended fast: Hidden Power (Ice)
#   Recommended charged: ['Crush Grip*', 'Thunder']
#   ✅ Successfully fixed!
#
# Retrying 46/54: Spoink (Shadow)
#   Overall: 1896
#   Fast moves: 2 (['Zen Headbutt', 'Splash'])
#   Charged moves: 4 (['Shadow Ball', 'Mirror Coat', 'Psybeam', 'Frustration†'])
#   Recommended fast: Zen Headbutt
#   Recommended charged: ['Shadow Ball', 'Mirror Coat']
#   ✅ Successfully fixed!
#
# Retrying 47/54: Skiddo
#   Overall: 1896
#   Fast moves: 2 (['Zen Headbutt', 'Splash'])
#   Charged moves: 4 (['Shadow Ball', 'Mirror Coat', 'Psybeam', 'Frustration†'])
#   Recommended fast: Zen Headbutt
#   Recommended charged: ['Shadow Ball', 'Mirror Coat']
#   ✅ Successfully fixed!
#
# Retrying 47/54: Skiddo
#   Overall: 1722
#   Fast moves: 2 (['Rock Smash', 'Zen Headbutt'])
#   Charged moves: 3 (['Seed Bomb', 'Rock Slide', 'Brick Break'])
#   Recommended fast: Rock Smash
#   Recommended charged: ['Seed Bomb', 'Rock Slide']
#   ✅ Successfully fixed!
#
# Retrying 48/54: Spoink
#   Overall: 1722
#   Fast moves: 2 (['Rock Smash', 'Zen Headbutt'])
#   Charged moves: 3 (['Seed Bomb', 'Rock Slide', 'Brick Break'])
#   Recommended fast: Rock Smash
#   Recommended charged: ['Seed Bomb', 'Rock Slide']
#   ✅ Successfully fixed!
#
# Retrying 48/54: Spoink
#   Overall: 1896
#   Fast moves: 2 (['Zen Headbutt', 'Splash'])
#   Charged moves: 4 (['Shadow Ball', 'Return†', 'Mirror Coat', 'Psybeam'])
#   Recommended fast: Zen Headbutt
#   Recommended charged: ['Shadow Ball', 'Return†']
#   ✅ Successfully fixed!
#
# Retrying 49/54: Clefairy
#   Overall: 1896
#   Fast moves: 2 (['Zen Headbutt', 'Splash'])
#   Charged moves: 4 (['Shadow Ball', 'Return†', 'Mirror Coat', 'Psybeam'])
#   Recommended fast: Zen Headbutt
#   Recommended charged: ['Shadow Ball', 'Return†']
#   ✅ Successfully fixed!
#
# Retrying 49/54: Clefairy
#   Overall: 1664
#   Fast moves: 2 (['Zen Headbutt', 'Pound'])
#   Charged moves: 4 (['Disarming Voice', 'Swift', 'Moonblast', 'Body Slam'])
#   Recommended fast: Zen Headbutt
#   Recommended charged: ['Disarming Voice', 'Swift']
#   ✅ Successfully fixed!
#
# Retrying 50/54: Kadabra
#   Overall: 1664
#   Fast moves: 2 (['Zen Headbutt', 'Pound'])
#   Charged moves: 4 (['Disarming Voice', 'Swift', 'Moonblast', 'Body Slam'])
#   Recommended fast: Zen Headbutt
#   Recommended charged: ['Disarming Voice', 'Swift']
#   ✅ Successfully fixed!
#
# Retrying 50/54: Kadabra
#   Overall: 1356
#   Fast moves: 2 (['Psycho Cut', 'Confusion'])
#   Charged moves: 4 (['Shadow Ball', 'Dazzling Gleam', 'Return†', 'Psybeam'])
#   Recommended fast: Psycho Cut
#   Recommended charged: ['Shadow Ball', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 51/54: Unown
#   Overall: 1356
#   Fast moves: 2 (['Psycho Cut', 'Confusion'])
#   Charged moves: 4 (['Shadow Ball', 'Dazzling Gleam', 'Return†', 'Psybeam'])
#   Recommended fast: Psycho Cut
#   Recommended charged: ['Shadow Ball', 'Dazzling Gleam']
#   ✅ Successfully fixed!
#
# Retrying 51/54: Unown
#   Overall: 1413
#   Fast moves: 16 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fire)', 'Hidden Power (Flying)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)'])
#   Charged moves: 1 (['Struggle'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Struggle']
#   ✅ Successfully fixed!
#
# Retrying 52/54: Mienfoo
#   Overall: 1413
#   Fast moves: 16 (['Hidden Power (Psychic)', 'Hidden Power (Ground)', 'Hidden Power (Rock)', 'Hidden Power (Ice)', 'Hidden Power (Fire)', 'Hidden Power (Flying)', 'Hidden Power (Water)', 'Hidden Power (Electric)', 'Hidden Power (Fighting)', 'Hidden Power (Grass)', 'Hidden Power (Ghost)', 'Hidden Power (Dark)', 'Hidden Power (Dragon)', 'Hidden Power (Steel)', 'Hidden Power (Bug)', 'Hidden Power (Poison)'])
#   Charged moves: 1 (['Struggle'])
#   Recommended fast: Hidden Power (Psychic)
#   Recommended charged: ['Struggle']
#   ✅ Successfully fixed!
#
# Retrying 52/54: Mienfoo
#   Overall: 1563
#   Fast moves: 2 (['Low Kick', 'Pound'])
#   Charged moves: 4 (['High Jump Kick*', 'Brick Break', 'Focus Blast', 'Low Sweep'])
#   Recommended fast: Low Kick
#   Recommended charged: ['High Jump Kick*', 'Brick Break']
#   ✅ Successfully fixed!
#
# Retrying 53/54: Slaking
#   Overall: 1563
#   Fast moves: 2 (['Low Kick', 'Pound'])
#   Charged moves: 4 (['High Jump Kick*', 'Brick Break', 'Focus Blast', 'Low Sweep'])
#   Recommended fast: Low Kick
#   Recommended charged: ['High Jump Kick*', 'Brick Break']
#   ✅ Successfully fixed!
#
# Retrying 53/54: Slaking
#   Overall: 1608
#   Fast moves: 1 (['Yawn'])
#   Charged moves: 4 (['Body Slam*', 'Earthquake', 'Play Rough', 'Hyper Beam'])
#   Recommended fast: Yawn
#   Recommended charged: ['Body Slam*', 'Earthquake']
#   ✅ Successfully fixed!
#
# Retrying 54/54: Slaking (Shadow)
#   Overall: 1608
#   Fast moves: 1 (['Yawn'])
#   Charged moves: 4 (['Body Slam*', 'Earthquake', 'Play Rough', 'Hyper Beam'])
#   Recommended fast: Yawn
#   Recommended charged: ['Body Slam*', 'Earthquake']
#   ✅ Successfully fixed!
#
# Retrying 54/54: Slaking (Shadow)
#   Overall: 1608
#   Fast moves: 1 (['Yawn'])
#   Charged moves: 5 (['Body Slam*', 'Earthquake', 'Play Rough', 'Hyper Beam', 'Frustration†'])
#   Recommended fast: Yawn
#   Recommended charged: ['Body Slam*', 'Earthquake']
#   ✅ Successfully fixed!
#
# 🎉 Fixed data saved to raw_data/pokemon_stats_moves_fixed.json
# Total Pokemon processed: 54
#   Overall: 1608
#   Fast moves: 1 (['Yawn'])
#   Charged moves: 5 (['Body Slam*', 'Earthquake', 'Play Rough', 'Hyper Beam', 'Frustration†'])
#   Recommended fast: Yawn
#   Recommended charged: ['Body Slam*', 'Earthquake']
#   ✅ Successfully fixed!
#
# 🎉 Fixed data saved to raw_data/pokemon_stats_moves_fixed.json
# Total Pokemon processed: 54

# %%
update_original_data_with_fixes()
# Out:
# 💾 Backup created: raw_data/pokemon_stats_moves_backup.json
# ✅ Updated: Zygarde (50% Forme)
# ✅ Updated: Mr. Mime
# ✅ Updated: Cherrim (Sunshine)
# ✅ Updated: Wyrdeer
# ✅ Updated: Nuzleaf
# ✅ Updated: Teddiursa
# ✅ Updated: Onix
# ✅ Updated: Zygarde (10% Forme)
# ✅ Updated: Ambipom
# ✅ Updated: Lycanroc (Dusk)
# ✅ Updated: Darmanitan (Galarian)
# ✅ Updated: Meowstic (Male)
# ✅ Updated: Mr. Rime
# ✅ Updated: Mr. Mime (Galarian)
# ✅ Updated: Rampardos
# ✅ Updated: Xatu
# ✅ Updated: Bergmite
# ✅ Updated: Bulbasaur (Shadow)
# ✅ Updated: Clawitzer
# ✅ Updated: Deerling
# ✅ Updated: Shaymin (Sky)
# ✅ Updated: Pupitar
# ✅ Updated: Inteleon
# ✅ Updated: Snover (Shadow)
# ✅ Updated: Drowzee
# ✅ Updated: Elgyem
# ✅ Updated: Gorebyss
# ✅ Updated: Accelgor
# ✅ Updated: Porygon-Z (Shadow)
# ✅ Updated: Flabebe
# ✅ Updated: Rowlet
# ✅ Updated: Reuniclus (Shadow)
# ✅ Updated: Throh
# ✅ Updated: Duosion (Shadow)
# ✅ Updated: Snubbull
# ✅ Updated: Solosis (Shadow)
# ✅ Updated: Deoxys (Speed)
# ✅ Updated: Anorith (Shadow)
# ✅ Updated: Munna
# ✅ Updated: Duosion
# ✅ Updated: Solosis
# ✅ Updated: Timburr (Shadow)
# ✅ Updated: Snubbull (Shadow)
# ✅ Updated: Anorith
# ✅ Updated: Regigigas (Shadow)
# ✅ Updated: Spoink (Shadow)
# ✅ Updated: Skiddo
# ✅ Updated: Spoink
# ✅ Updated: Clefairy
# ✅ Updated: Kadabra
# ✅ Updated: Unown
# ✅ Updated: Mienfoo
# ✅ Updated: Slaking
# ✅ Updated: Slaking (Shadow)
#
# 🎉 Successfully updated 54 Pokemon in raw_data/pokemon_stats_moves.json
# 📁 Original data backed up to: raw_data/pokemon_stats_moves_backup.json
